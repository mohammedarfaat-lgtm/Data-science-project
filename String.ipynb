# %%
oinnnnnnnnnn
print
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_34671/1036883289.py in <cell line: 0>()
# ----> 1 oinnnnnnnnnn
#       2 print
#
# NameError: name 'oinnnnnnnnnn' is not defined

# %%
name = "arfath"
print(name)

# %%
print("top mentor")
# Out:
# top mentor

# %%
print("hello india")
# Out:
# hello india

# %%
name = "name"
print(name)
# Out:
# name

# %%
student = "zaheer"
print (student)
# Out:
# zaheer

# %%
# prompt: roll = none

roll = None
print(roll)

# %%
# prompt:

# This code prints a series of strings and variables.

print("Hello world")  # Prints the string "Hello world"

name = "Arfath"  # Assigns the string "Arfath" to the variable `name`
print(name)  # Prints the value of the variable `name`, which is "Arfath"

print("Top Mentor")  # Prints the string "Top Mentor"

print("Hello India")  # Prints the string "Hello India"

name = "name"  # Assigns the string "name" to the variable `name`
print(name)  # Prints the value of the variable `name`, which is now "name"

student = "Zaheer"  # Assigns the string "Zaheer" to the variable `student`
print(student)  # Prints the value of the variable `student`, which is "Zaheer"

roll = None  # Assigns the value `None` to the variable `roll`
print(roll)  # Prints the value of the variable `roll`, which is `None`
# Out:
# Hello world
# Arfath
# Top Mentor
# Hello India
# name
# Zaheer
# None

# %%
india = "bangalore is in india"
print(india)
# Out:
# bangalore is in india

# %%
india = "bangalore is in india"
print(india[0],end=" ")
print(india[1],end=" ")
print(india[2],end=" ")
print(india[3],end=" ")
print(india[6],end=" ")
# Out:
# b a n g o

# %%
india = "bangaloe is in india"
print(india[1:7])
# Out:
# angalo

# %%
india = "25525544"
print(india[0:6])
# Out:
# 255255

# %%
firstname = "bangalore"
middlename= "is in"
lastname = "india"
print(firstname+" "+middlename+" "+lastname)
# Out:
# bangalore is in india

# %%
name = "arfath"
print(name.upper())
# Out:
# ARFATH

# %%
name="arfath"
print(name.upper())
# Out:
# ARFATH

# %%
name="salman"
formatted_string="hello, i am {} from india".format(name)
print(formatted_string)
# Out:
# hello, i am salman from india

# %%
name="arfath"
formatted_string="hello, i am {} from india".format(name)
print(formatted_string)
# Out:
# hello, i am arfath from india

# %%
name = "arfath"
age = 25
k = "hello, i am {} form india, my age is {}".format(name,age)
print(k)
# Out:
# hello, i am arfath form india, my age is 25

# %%
name=  "salmaan"
print(len(name))
# Out:
# 7

# %%
name= "abc " *50
print(name)
# Out:
# abc abc abc abc abc abc abc abc abc abc abc abc abc abc abc abc abc abc abc abc abc abc abc abc abc abc abc abc abc abc abc abc abc abc abc abc abc abc abc abc abc abc abc abc abc abc abc abc abc abc

# %%
member = "arfath"
logic= "a" in member
print(logic)
# Out:
# True

# %%
name="aditya"
logic="i" in name
print(logic)
# Out:
# True

# %%
name="arfath"
logic= "" in name
print(logic)
# Out:
# True

# %%
comparison = "abc"== "def"
print(comparison)
# Out:
# False

# %%
help("keywords")
# Out:
# Here is a list of the Python keywords.  Enter any keyword to get more help.
#
# False               class               from                or
# None                continue            global              pass
# True                def                 if                  raise
# and                 del                 import              return
# as                  elif                in                  try
# assert              else                is                  while
# async               except              lambda              with
# await               finally             nonlocal            yield
# break               for                 not

# %%
value = None
print(value)
# Out:
# None

# %%
help("for")
# Out:
# The "for" statement
# *******************
#
# The "for" statement is used to iterate over the elements of a sequence
# (such as a string, tuple or list) or other iterable object:
#
#    for_stmt ::= "for" target_list "in" expression_list ":" suite
#                 ["else" ":" suite]
#
# The expression list is evaluated once; it should yield an iterable
# object.  An iterator is created for the result of the
# "expression_list".  The suite is then executed once for each item
# provided by the iterator, in the order returned by the iterator.  Each
# item in turn is assigned to the target list using the standard rules
# for assignments (see Assignment statements), and then the suite is
# executed.  When the items are exhausted (which is immediately when the
# sequence is empty or an iterator raises a "StopIteration" exception),
# the suite in the "else" clause, if present, is executed, and the loop
# terminates.
#
# A "break" statement executed in the first suite terminates the loop
# ...

# %%
help("in")
# Out:
# Membership test operations
# **************************
#
# The operators "in" and "not in" test for membership.  "x in s"
# evaluates to "True" if *x* is a member of *s*, and "False" otherwise.
# "x not in s" returns the negation of "x in s".  All built-in sequences
# and set types support this as well as dictionary, for which "in" tests
# whether the dictionary has a given key. For container types such as
# list, tuple, set, frozenset, dict, or collections.deque, the
# expression "x in y" is equivalent to "any(x is e or x == e for e in
# y)".
#
# For the string and bytes types, "x in y" is "True" if and only if *x*
# is a substring of *y*.  An equivalent test is "y.find(x) != -1".
# Empty strings are always considered to be a substring of any other
# string, so """ in "abc"" will return "True".
#
# For user-defined classes which define the "__contains__()" method, "x
# in y" returns "True" if "y.__contains__(x)" returns a true value, and
# "False" otherwise.
#
# ...

# %%
comparision="aba"=="abc"
print(comparision)
# Out:
# False

# %%
name="alice"
sentence="hello, world!"
multiline= "this is a multiline string"
print(name)
print(sentence)
print(multiline)
# Out:
# alice
# hello, world!
# this is a multiline string

# %%
name="alice"
sentence="hello, world!"
multiline = "this is a multiline string"
print(name)
print(sentence)
print(multiline)
# Out:
# alice
# hello, world!
# this is a multiline string

# %%
name= 10
name= 20
name=30
name=500
name=1
print(name)
# Out:
# 1

# %%
my_string="0123456789"
string2=my_string[0:10:3]
print(string2)
# Out:
# 0369

# %%
pattern="20"*10
print(pattern)
# Out:
# 20202020202020202020

# %%
sentence="hello world"
result= sentence.replace("hello world","arfath")
print(result)
# Out:
# arfath

# %%
string="hello world"
result=string.capitalize()
print(result)
# Out:
# Hello world

# %%
string="hello WORLD"
print(string.casefold())
# Out:
# hello world

# %%
string="hello"
result=string.center(2500)
print(result)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %%
string="hello world"
result=string.count("j")
print(result)
# Out:
# 0

# %%
string="hello world"
result=string.encode()
print(result)
# Out:
# b'hello world'

# %%
string="hello world"
result=string.endswith("hello")
print(result)
# Out:
# False

# %%
string="hello\tworld"
result=string.expandtabs(8)
print(result)
# Out:
# hello   world

# %%
print("hello\n\n\n\t\t\t\t\tworld")
# Out:
# hello
#
#
# 					world

# %%
print("I\n\tam\n\t\n\t\tlearning\n\t\t\t\tdatascience")
# Out:
# I
# 	am
#
# 		learning
# 				datascience

# %%
print("I\n\tam\n\t\tlearing\n\t\t\tdatascience")
# Out:
# I
# 	am
# 		learing
# 			datascience

# %%
string="hello\tworld"
print(string.expandtabs(25))
# Out:
# hello                    world

# %%
string='hello world'
result=string.find("l")
print(result)
# Out:
# 2

# %%
print+("
ffffffffffffffffffffffffffffffffffffff

# %%
person={"name":"alice","age":"25"}
result="my name is {name} and i am {age} years old.".format_map(person)
print(result)
# Out:
# my name is alice and i am 25 years old.

# %%
string="hello world"
result=string.index("d")
print(result)
# Out:
# 10

# %%
person={"name":"arfath","age":"25"}
result= "my name is {name} and i am {age} year old".format_map(person)
print(result)
# Out:
# my name is arfath and i am 25 year old

# %%
# prompt:

# !git clone https://github.com/tensorflow/models.git

# %%
person={"name":"arfath", "age":25}
result="my name is {name} and i am {age} years old".format_map(person)
print(result)
# Out:
# my name is arfath and i am 25 years old

# %%
string="hello world"
result=string.index("o")
print
# Out:
# 2
