# %%
score = int(input("your score:"))
if 90<= score <= 100:
 print("A")
if 80<= score <= 89:
 print("B")
# Out:
# your score:85
# B

# %%
alphabet=input("enter alphabet: ")
if alphabet in ("a","e","i","o","u"):
  print("vowel")
else:
  print('odd')
# Out:
# enter alphabet: p
# odd

# %%
name="kiran"
substring="my  name is {}".format(name)
print(name)
# Out:
# kiran

# %%
x=int(input("enter the side of the triangle x: "))
y=int(input("enter the side of the triangle y: "))
z=int(input("enter the side of the triangle z: "))
if x== y == z:
  print("qulateral triangle")
if x== z == y == x
# Out:
# enter the side of the triangle x: 2
# enter the side of the triangle y: 2
# enter the side of the triangle z: 2
# qulateral triangle

# %%
num= int(input("enter the number"))
print(num*-1)
# Out:
# enter the number25
# -25

# %%
tuple
# Out:
# tuple

# %%
a=()
type(a)
# Out:
# tuple

# %%
a=(2,3)
print(type (a))
# Out:
# <class 'tuple'>

# %%
a=(2)
print(type(a))
# Out:
# <class 'int'>

# %%
a=2
print(type(a))
# Out:
# <class 'int'>

# %%
a=2,3
print(type(a))
# Out:
# <class 'tuple'>

# %%
a,b,c=10,20,30
print(a)
print(b)
print(c)
# Out:
# 10
# 20
# 30

# %%
a=(101,102,103)
x,y,z=a

# %%
print(a)
# Out:
# (101, 102, 103)

# %%
roll= ((1,2),(3,4),(5,6))
roll
# Out:
# ((1, 2), (3, 4), (5, 6))

# %%
print(roll[0])
# Out:
# (1, 2)

# %%
print(roll[1])
# Out:
# (3, 4)

# %%
print(roll[2])
# Out:
# (5, 6)

# %%
print(roll[1][1])
# Out:
# 4

# %%
print(roll[[2][0]])
# Out:
# (5, 6)

# %%
print(roll[0][1])
# Out:
# 2

# %%
a=(5,)
print(type(a))
# Out:
# <class 'tuple'>
