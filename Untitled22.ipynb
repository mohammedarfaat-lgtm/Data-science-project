# %%
print("hello world")
# Out:
# hello world

# %%
name="arfath"
print("name")
# Out:
# name

# %%
string="my name is arfath"
print(string)
# Out:
# my name is arfath

# %%
for i in range(1,11):
  print(i,"subhanallah alhumdulliha walaa eliha illahlahu wallau akbar")
# Out:
# 1 subhanallah alhumdulliha walaa eliha illahlahu wallau akbar
# 2 subhanallah alhumdulliha walaa eliha illahlahu wallau akbar
# 3 subhanallah alhumdulliha walaa eliha illahlahu wallau akbar
# 4 subhanallah alhumdulliha walaa eliha illahlahu wallau akbar
# 5 subhanallah alhumdulliha walaa eliha illahlahu wallau akbar
# 6 subhanallah alhumdulliha walaa eliha illahlahu wallau akbar
# 7 subhanallah alhumdulliha walaa eliha illahlahu wallau akbar
# 8 subhanallah alhumdulliha walaa eliha illahlahu wallau akbar
# 9 subhanallah alhumdulliha walaa eliha illahlahu wallau akbar
# 10 subhanallah alhumdulliha walaa eliha illahlahu wallau akbar

# %%
alphabet= input("enter the alphabet")
if alphabet in "aeiou":
  print("vowel")
else:
  print("not a vowel")
# Out:
# enter the alphabet450lkl
# not a vowel

# %%
number=int(input("enter the  number"))
if number%2==0:
  print("even")
else:
  print("odd")
# Out:
#   File "<ipython-input-29-7f1367ad033f>", line 1
#     number=input("enter the  number"))
#                                      ^
# SyntaxError: unmatched ')'

# %%
alphabet=input("enter the alphabet:")
if alphabet in "aeiou":
  print("vowel")
else:
  print("odd")
# Out:
# enter the alphabet:aeiou
# vowel
