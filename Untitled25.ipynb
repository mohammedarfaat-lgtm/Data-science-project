# %%
my_float=123.456
converted_string=str(my_float)
print(converted_string)
# Out:
# 123.456

# %%
converted_integer = bool(1)
print(converted_integer)
# Out:
# True

# %%
integer_value = int("123")
float_value = float(integer_value)
print(float_value)
# Out:
# 123.0

# %%
binary_string = "101"
integer_value = int(binary_string, 2)
print(integer_value)
# Out:
# 5

# %%
hex_string = "0xff"
integer_value = int(hex_string, 16)
print(integer_value)
# Out:
# 255

# %%
string_value = "123.456"
    float_value = float(string_value)
    integer_value = int(float_value)

    print(integer_value)
except ValueError:
    print("Error: Cannot convert the string to an integer.")
# Out:
# 123

# %%
 Convert a list `[1, 2, 3]` to a string.

# %%
string_value = "abc"
    integer_value = int(string_value)
    print("Conversion successful:", integer_value)
except ValueError:
    print("Error: Cannot convert string to integer.")
# Out:
# Error: Cannot convert string to integer.

# %%
now=datetime.datetime.now()
print("Current date and time:", now)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-7828a1804bb0> in <cell line: 1>()
# ----> 1 now = datetime.datetime.now()
#       2 print("Current date and time:", now)
#       3
#
# NameError: name 'datetime' is not defined

# %%
now= datetime.datetime.now()
print("Current date and time:",now)
# Out:
# Current date and time: 2024-09-18 17:22:03.220076

# %%
import datetime # imports the datetime module

now = datetime.datetime.now()
print("Current date and time:", now)
# Out:
# Current date and time: 2024-09-18 17:20:51.156885
