# %%
from datetime import datetime
import pytz

tz = pytz.timezone('US/Eastern')
dt_before = tz.localize(datetime(2024, 3, 10, 1, 30))
dt_after = tz.localize(datetime(2024, 3, 10, 3, 30))
print("Before transition:", dt_before, "After transition:", dt_after)
# Out:
# Before transition: 2024-03-10 01:30:00-05:00 After transition: 2024-03-10 03:30:00-04:00

# %%
from datetime import datetime
import pytz
tz= pytz.timezone("US/Eastern")
dt_before=tz.localize(datetime(2024,3,10,1,30))
dt_after=tz.localize(datetime(2024,3,10,3,30))
print("Before transition:",dt_before,"After transiton:",dt_after)
# Out:
# Before transition: 2024-03-10 01:30:00-05:00 After transiton: 2024-03-10 03:30:00-04:00

# %%
import locale
from datetime import datetime

locale.setlocale(locale.LC_TIME, 'de_DE')
german_date = datetime.now().strftime('%A, %d. %B %Y')
print("German date:", german_date)
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# <ipython-input-8-295c2133c5f5> in <cell line: 4>()
#       2 from datetime import datetime
#       3
# ----> 4 locale.setlocale(locale.LC_TIME, 'de_DE')
#       5 german_date = datetime.now().strftime('%A, %d. %B %Y')
#       6 print("German date:", german_date)
#
# /usr/lib/python3.10/locale.py in setlocale(category, locale)
#     618         # convert to string
#     619         locale = normalize(_build_localename(locale))
# --> 620     return _setlocale(category, locale)
#     621
#     622 def resetlocale(category=LC_ALL):
#
# Error: unsupported locale setting

# %%
import locale
from datetime import datetime

locale.setlocale(locale.LC_TIME, 'de_DE')
german_date = datetime.now().strftime('%A, %d. %B %Y')
print("German date:", german_date)
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# <ipython-input-9-a797383d3fda> in <cell line: 4>()
#       2 from datetime import datetime
#       3
# ----> 4 locale.setlocale(locale.LC_TIME, 'de_DE')
#       5 german_date = datetime.now().strftime('%A, %d. %B %Y')
#       6 print("German date:", german_date)
#
# /usr/lib/python3.10/locale.py in setlocale(category, locale)
#     618         # convert to string
#     619         locale = normalize(_build_localename(locale))
# --> 620     return _setlocale(category, locale)
#     621
#     622 def resetlocale(category=LC_ALL):
#
# Error: unsupported locale setting

# %%
import locale
from datetime import datetime
locale.setlocale(locale.LC_TIME, 'de_DE')
german_date = datetime.now().strftime('%A, %d. %B %Y')
print("German date:", german_date)
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# <ipython-input-10-e4798be0b3be> in <cell line: 3>()
#       1 import locale
#       2 from datetime import datetime
# ----> 3 locale.setlocale(locale.LC_TIME, 'de_DE')
#       4 german_date = datetime.now().strftime('%A, %d. %B %Y')
#       5 print("German date:", german_date)
#
# /usr/lib/python3.10/locale.py in setlocale(category, locale)
#     618         # convert to string
#     619         locale = normalize(_build_localename(locale))
# --> 620     return _setlocale(category, locale)
#     621
#     622 def resetlocale(category=LC_ALL):
#
# Error: unsupported locale setting

# %%
print("hello world")
# Out:
# hello world

# %%
print("hello world")
# Out:
# hello world
