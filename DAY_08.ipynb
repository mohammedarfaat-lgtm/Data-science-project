# %%
mylist=[1,2,3,4,5,]
print(mylist)
# Out:
# [1, 2, 3, 4, 5]

# %%
mytuple=(1,2,3,4,)
print(mytuple)
# Out:
# (1, 2, 3, 4)

# %%
mytuple=1,2,3,4,5
print(mytuple)
# Out:
# (1, 2, 3, 4, 5)

# %%
mydict={1:"ram",2:"sham"}
print(mydict)
# Out:
# {1: 'ram', 2: 'sham'}

# %%
myset={1,2,3,4,5,}
print(type(myset))
# Out:
# <class 'set'>

# %%
myset={}
print(type(myset) )
# Out:
# <class 'dict'>

# %%
#unorder collection
myset={1,2,3,"ram", "keerthi",400,"sham"}
print(myset)
# Out:
# {'keerthi', 1, 2, 'ram', 3, 'sham', 400}

# %%
mylist=[1,2,4,"sham","deeepa",600,700,"ramu"]
print(mylist)
# Out:
# [1, 2, 4, 'sham', 'deeepa', 600, 700, 'ramu']

# %%
mylist=[1,2,2,4]
print(mylist)
# Out:
# [1, 2, 2, 4]

# %%
myset={1,2,2,4}
print(myset)
# Out:
# {1, 2, 4}

# %%
number=set({1,2,2,4})
print(number)
# Out:
# {1, 2, 4}

# %%
inp=[1,2,2,4]
num=set(inp)
print(num)
# Out:
# {1, 2, 4}

# %%
# tuple is immutable
my_tuple = (1, 2, 3)
my_tuple[0] = 10
print(my_tuple[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-9357fc8eb770> in <cell line: 3>()
#       1 # tuple is immutable
#       2 my_tuple = (1, 2, 3)
# ----> 3 my_tuple[0] = 10
#       4 print(my_tuple[0])
#
# TypeError: 'tuple' object does not support item assignment

# %%
#sets are mutable means we can add or remove after creation

# %%
myset={1,2,3,4,}
inp=int(input("enter the number:"))
myset.add(inp)
print(myset)
# Out:
# enter the number:25
# {1, 2, 3, 4, 25}

# %%
myset={1,2,3,4,}
inp=int(input("enter the number:"))
myset.remove(inp)
print(myset)
# Out:
# enter the number:4
# {1, 2, 3}

# %%
kfc={"noodles","pizza","burger","samosa"}
mcd={"pizza","wadapav","momos","bhelpuri","rolls"}

rest=kfc| mcd
print(rest)
# Out:
# {'wadapav', 'noodles', 'bhelpuri', 'burger', 'rolls', 'samosa', 'momos', 'pizza'}

# %%
kfc={"noodles","pizza","burger","samosa"}
mcd={"pizza","wadapav","momos","bhelpuri","rolls"}

rest=kfc &  mcd
print(rest)
# Out:
# {'pizza'}

# %%
kfc={"noodles","pizza","burger","samosa"}
mcd={"pizza","wadapav","momos","bhelpuri","rolls"}

rest=kfc -  mcd
print(rest)
# Out:
# {'noodles', 'burger', 'samosa'}

# %%
kfc={"noodles","pizza","burger","samosa"}
mcd={"pizza","wadapav","momos","bhelpuri","rolls"}

rest= mcd-kfc
print(rest)
# Out:
# {'wadapav', 'bhelpuri', 'rolls', 'momos'}

# %%
kfc={"noodles","pizza","burger","samosa"}
mcd={"pizza","wadapav","momos","bhelpuri","rolls"}

rest= kfc^mcd
print(rest)
# Out:
# {'wadapav', 'momos', 'samosa', 'noodles', 'burger', 'rolls', 'bhelpuri'}

# %%
squared_set={x**2 for x in range(5)}
print(squared_set)
# Out:
# {0, 1, 4, 9, 16}

# %%
squared_set={x+2 for x in range(5)}
print(squared_set)
# Out:
# {2, 3, 4, 5, 6}

# %%
squared_set={x-2 for x in range(3)}
print(squared_set)
# Out:
# {0, -2, -1}

# %%
# set is unorder and list is order

# %%
for x in range(4):
  print(x-1)
# Out:
# -1
# 0
# 1
# 2

# %%
squared_set={x-1 for x in range(3)}
print(squared_set)
# Out:
# {0, 1, -1}

# %%
myset={}
print(myset)
# Out:
# {}

# %%
myset={1,2,3,}
inp=int(input("enter the number:"))
myset.add(inp)
print(myset)
# Out:
# enter the number:5
# {1, 2, 3, 5}

# %%
myset={1,2,3,4,5,}
inp=int(input("enter the number:"))
myset.remove(inp)
print(myset)
# Out:
# enter the number:5
# {1, 2, 3, 4}

# %%
# to check 3 is present in the set
set={1,2,3,}
if 3 in set:
  print("present")
else:
  print("absent")
# Out:
# present

# %%
# to check 3 is present in the set
set={1,2,3}
print(3 in set)
# Out:
# True

# %%
# to chect the length of set
set={1,2,3,4,5,}
print(len(set))
# Out:
# 5

# %%
set={1,2,3,4,5}
set.clear()
print(set)
# Out:
# set()

# %%
set={3,4,5,6,7}
print(len(set))
# Out:
# 5

# %%
# pass

# %%
for i in range(1,10):
  print("india-",i, "0009")
# Out:
# india- 1 0009
# india- 2 0009
# india- 3 0009
# india- 4 0009
# india- 5 0009
# india- 6 0009
# india- 7 0009
# india- 8 0009
# india- 9 0009

# %%
for i in range(1,10):
  pass
  print(i,"hello")
# Out:
# 1 hello
# 2 hello
# 3 hello
# 4 hello
# 5 hello
# 6 hello
# 7 hello
# 8 hello
# 9 hello

# %%
def ram():
  return "hello"

# %%
var=ram()
print(var * 2)
# Out:
# hellohello

# %%
def login():
  print("i am in login")

def signup():
  pass

def like():
  print("i am in like fuction")
login()
signup()
like()
# Out:
# i am in login
# i am in like fuction

# %%
############################ practice according to the task

# %%
set={1,2,3,4,5}
set.clear()
print(set)
# Out:
# set()

# %%
myset={1,2,3,}
inp=int(input("enter th number:"))
myset.add(5)
print(myset)
# Out:
# enter th number:5
# {1, 2, 3, 5}

# %%
myset={1,2,3,}
inp=int(input("enter th number:"))
myset.remove(2)
print(myset)
# Out:
# enter th number:2
# {1, 3}

# %%
myset={1,2,3,4,5}
print(len(myset))
# Out:
# 5

# %%
myset={1, 2, 3, 4, 5}
myset.clear()
print(myset)
# Out:
# set()

# %%
set={3,4,5,6,7,}
print(set)
# Out:
# {3, 4, 5, 6, 7}

# %%
print(len(set))
# Out:
# 5

# %%
seta={1,2,3}
setb={3,4,5}
print(seta|setb)
# Out:
# {1, 2, 3, 4, 5}

# %%
seta={1,2,3}
setb={3,4,5}
print(seta^setb)
# Out:
# {1, 2, 4, 5}

# %%
seta={1,2,3}
myset={4,5,6}
myset.isdisjoint(seta)
# Out:
# True

# %%
squared_set={x**2 for x in range(6)}
print(squared_set)
# Out:
# {0, 1, 4, 9, 16, 25}

# %%
myset={1,2,3,4,5}
myset.remove(5)
print(myset)
# Out:
# {1, 2, 3, 4}

# %%
my_set = {1, 2, 3}
removed_element = my_set.pop()
print("Removed element:", removed_element)
# Out:
# Removed element: 1

# %%
seta={1,2,3}
setb={1,2,3}
seta.issubset(setb)
# Out:
# True

# %%
seta={1,2,3}
seta.update({4,5})
print(seta)
# Out:
# {1, 2, 3, 4, 5}

# %%
a={1, 2}
b={2, 3}
c={3, 4}
print(a|b|c)
# Out:
# {1, 2, 3, 4}
