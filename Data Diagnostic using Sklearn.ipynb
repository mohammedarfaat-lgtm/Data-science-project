# %%
# !pip install scikit_learn

# %%
from sklearn.datasets import fetch_california_housing

# %%
california= fetch_california_housing(as_frame=True)
california
# Out:
# {'data':        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
#  0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
#  1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
#  2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
#  3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
#  4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#  ...       ...       ...       ...        ...         ...       ...       ...
#  20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
#  20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
#  20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
#  20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
#  20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#         Longitude
# ...

# %%
california_df=california.frame
california_df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  MedHouseVal
# ...

# %%
california_df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  MedHouseVal
# 0    -122.23        4.526
# 1    -122.22        3.585
# 2    -122.24        3.521
# 3    -122.25        3.413
# 4    -122.25        3.422

# %%
california_df["Population"]
# Out:
# 0         322.0
# 1        2401.0
# 2         496.0
# 3         558.0
# 4         565.0
#           ...
# 20635     845.0
# 20636     356.0
# 20637    1007.0
# 20638     741.0
# 20639    1387.0
# Name: Population, Length: 20640, dtype: float64

# %%
def data_diagnostics(df):
  d={
      "missing_values":df.isnull().sum(),
      "data_types":df.dtypes,
      "numeric_stats":df.describe()
     }
  return d

# %%
result=data_diagnostics(california_df)
result
# Out:
# {'missing_values': MedInc         0
#  HouseAge       0
#  AveRooms       0
#  AveBedrms      0
#  Population     0
#  AveOccup       0
#  Latitude       0
#  Longitude      0
#  MedHouseVal    0
#  dtype: int64,
#  'data_types': MedInc         float64
#  HouseAge       float64
#  AveRooms       float64
#  AveBedrms      float64
#  Population     float64
#  AveOccup       float64
#  Latitude       float64
#  Longitude      float64
#  MedHouseVal    float64
#  dtype: object,
#  'numeric_stats':              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
#  count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
#  mean       3.870671     28.639486      5.429000      1.096675   1425.476744
#  std        1.899822     12.585558      2.474173      0.473911   1132.462122
#  min        0.499900      1.000000      0.846154      0.333333      3.000000
#  25%        2.563400     18.000000      4.440716      1.006079    787.000000
# ...

# %%
california_df.isnull().sum()
# Out:
# MedInc         0
# HouseAge       0
# AveRooms       0
# AveBedrms      0
# Population     0
# AveOccup       0
# Latitude       0
# Longitude      0
# MedHouseVal    0
# dtype: int64

# %%
import pandas as pd

# %%
df=pd.read_csv("laptop_data.csv")
df
# Out:
#       Brand           Model  Age(Years)  Condition Specifications  \
# 0      Dell          XPS 13           3       Good       Intel i7
# 1        HP   EliteBook 840           4       Fair       Intel i5
# 2     Apple     MacBook Air           3  Excellent       Apple M1
# 3    Lenovo  IdeaPad Flex 5           3       Good    AMD Ryzen 5
# 4   Samsung      Notebook 7           5       Fair       Intel i5
# ..      ...             ...         ...        ...            ...
# 87       HP   Chromebook 14           4       Fair  Intel Celeron
# 88    Apple     MacBook Pro           2  Excellent       Intel i7
# 89     Asus    VivoBook S15           3       Good       Intel i5
# 90     Acer          Spin 5           4       Fair       Intel i7
# 91   Lenovo     Legion Y740           3       Good       Intel i7
#
#     Original_Price  Battery Life (hrs) Storage Type  Screen Size (inches)
# 0           120000                   8          SSD                  13.3
# ...

# %%
df
# Out:
#       Brand           Model  Age(Years)  Condition Specifications  \
# 0      Dell          XPS 13           3       Good       Intel i7
# 1        HP   EliteBook 840           4       Fair       Intel i5
# 2     Apple     MacBook Air           3  Excellent       Apple M1
# 3    Lenovo  IdeaPad Flex 5           3       Good    AMD Ryzen 5
# 4   Samsung      Notebook 7           5       Fair       Intel i5
# ..      ...             ...         ...        ...            ...
# 87       HP   Chromebook 14           4       Fair  Intel Celeron
# 88    Apple     MacBook Pro           2  Excellent       Intel i7
# 89     Asus    VivoBook S15           3       Good       Intel i5
# 90     Acer          Spin 5           4       Fair       Intel i7
# 91   Lenovo     Legion Y740           3       Good       Intel i7
#
#     Original_Price  Battery Life (hrs) Storage Type  Screen Size (inches)
# 0           120000                   8          SSD                  13.3
# ...

# %%
df.tail()
# Out:
#      Brand          Model  Age(Years)  Condition Specifications  \
# 87      HP  Chromebook 14           4       Fair  Intel Celeron
# 88   Apple    MacBook Pro           2  Excellent       Intel i7
# 89    Asus   VivoBook S15           3       Good       Intel i5
# 90    Acer         Spin 5           4       Fair       Intel i7
# 91  Lenovo    Legion Y740           3       Good       Intel i7
#
#     Original_Price  Battery Life (hrs) Storage Type  Screen Size (inches)
# 87           20000                  10          HDD                  14.0
# 88          170000                   8          SSD                  13.3
# 89           80000                   8          SSD                  15.6
# 90           75000                   7          HDD                  13.5
# 91          150000                   5          SSD                  15.6

# %%
df.head()
# Out:
#      Brand           Model  Age(Years)  Condition Specifications  \
# 0     Dell          XPS 13           3       Good       Intel i7
# 1       HP   EliteBook 840           4       Fair       Intel i5
# 2    Apple     MacBook Air           3  Excellent       Apple M1
# 3   Lenovo  IdeaPad Flex 5           3       Good    AMD Ryzen 5
# 4  Samsung      Notebook 7           5       Fair       Intel i5
#
#    Original_Price  Battery Life (hrs) Storage Type  Screen Size (inches)
# 0          120000                   8          SSD                  13.3
# 1           80000                   5          HDD                  14.0
# 2          100000                  15          SSD                  13.3
# 3           60000                   7          SSD                  14.0
# 4           70000                   4          HDD                  15.6

# %%
df.isnull()
# Out:
#     Brand  Model  Age(Years)  Condition  Specifications  Original_Price  \
# 0   False  False       False      False           False           False
# 1   False  False       False      False           False           False
# 2   False  False       False      False           False           False
# 3   False  False       False      False           False           False
# 4   False  False       False      False           False           False
# ..    ...    ...         ...        ...             ...             ...
# 87  False  False       False      False           False           False
# 88  False  False       False      False           False           False
# 89  False  False       False      False           False           False
# 90  False  False       False      False           False           False
# 91  False  False       False      False           False           False
#
#     Battery Life (hrs)  Storage Type  Screen Size (inches)
# ...

# %%
df.isnull().sum()
# Out:
# Brand                   0
# Model                   0
# Age(Years)              0
# Condition               0
# Specifications          0
# Original_Price          0
# Battery Life (hrs)      0
# Storage Type            0
# Screen Size (inches)    0
# dtype: int64

# %%
def data_diagnostics():
  pass

# %%
def data_diagnostics(df):
  diagnostics={
  "first five data":df.head(),
  "last five data":df.tail(),
  "Missing values":df.isnull().sum()
  }
  return diagnostics

# %%
data_diagnostics(df)
# Out:
# {'first five data':      Brand           Model  Age(Years)  Condition Specifications  \
#  0     Dell          XPS 13           3       Good       Intel i7
#  1       HP   EliteBook 840           4       Fair       Intel i5
#  2    Apple     MacBook Air           3  Excellent       Apple M1
#  3   Lenovo  IdeaPad Flex 5           3       Good    AMD Ryzen 5
#  4  Samsung      Notebook 7           5       Fair       Intel i5
#
#     Original_Price  Battery Life (hrs) Storage Type  Screen Size (inches)
#  0          120000                   8          SSD                  13.3
#  1           80000                   5          HDD                  14.0
#  2          100000                  15          SSD                  13.3
#  3           60000                   7          SSD                  14.0
#  4           70000                   4          HDD                  15.6  ,
#  'last five data':      Brand          Model  Age(Years)  Condition Specifications  \
# ...
