# %%
print("I\n\tam\n\t\tlearning\n\t\t\tdata science")
# Out:
# I
# 	am
# 		learning
# 			data science

# %%
string= "hello world"
result= string.find("l")
print(result)
# Out:
# 2

# %%
person = {"name": "alice", "age":25}
result= "my name is {name} and i am {age} years old.".format_map(person)
print (result)
# Out:
# my name is alice and i am 25 years old.

# %%
person={"name":"arfath","age":25}
result="my name is {name} and i am {age} 25 years old.".format_map(person)
print (result)
# Out:
# my name is arfath and i am 25 25 years old.

# %%
string="hello world"
result=string.index("z")
print(result)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-e61390984a6e> in <cell line: 2>()
#       1 string="hello world"
# ----> 2 result=string.index("z")
#       3 print(result)
#
# ValueError: substring not found

# %%
string="arfathqewewqe"
result=string.index("f")
print(result)
# Out:
# 2
