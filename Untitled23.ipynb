# %%
num = 25
converted=str(num)
print(converted)
# Out:
# 25

# %%
num = "3"
converted = float(num)
print(converted)
# Out:
# 3.0

# %%
num = 0.99
converted = str(num)
print(converted)
# Out:
# 0.99

# %%
flag=True
converted=int(flag)
print(converted)
# Out:
# 1

# %%
char = 'z'
converted = ord(char)
print(converted)
# Out:
# 122

# %%
num = "0xff"
converted = int(num, 17)
print(converted)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-92ed25d367a0> in <cell line: 2>()
#       1 num = "0xff"
# ----> 2 converted = int(num, 17)
#       3 print(converted)
#
# ValueError: invalid literal for int() with base 17: '0xff'

# %%
num="abc"
c=int(num)
print(c)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-f59145b8aed8> in <cell line: 2>()
#       1 num="abc"
# ----> 2 c=int(num)
#       3 print(c)
#
# ValueError: invalid literal for int() with base 10: 'abc'
