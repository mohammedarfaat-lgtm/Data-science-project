# %%
string="hello world"
result=string.find("world")
print(result)
# Out:
# 6

# %%
string="hello world"
result=string.index("o")
print(result)
# Out:
# 4

# %%
name="hello world"
result=string.index("r")
print(result)
# Out:
# 8

# %%
string="hello123"
result=string.isalnum()
print(result)
# Out:
# True

# %%
string="ara"
result=string.isalpha()
print(result)
# Out:
# True
