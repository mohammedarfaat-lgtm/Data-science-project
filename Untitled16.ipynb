# %%
my_list=["apple","banana","cherry"]
print(my_list)
# Out:
# ['apple', 'banana', 'cherry']

# %%
fruits=["apple","banana","cherry"]
print[1]="guava"
print(fruits)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-3af9b0a7b4de> in <cell line: 2>()
#       1 fruits=["apple","banana","cherry"]
# ----> 2 print[1]="guava"
#       3 print(fruits)
#
# TypeError: 'builtin_function_or_method' object does not support item assignment

# %%
sentence="CHANGE THE VALUE OF FIRST ITEM FROM THE LIST"
result=sentence.lower()
print(result)
# Out:
# change the value of first item from the list

# %%
fruits=["apple","banana","cherry"]
print(fruits)
# Out:
# ['apple', 'banana', 'cherry']

# %%
fruits.append("orange")

# %%
print(fruits)
# Out:
# ['apple', 'banana', 'cherry', 'orange', 'orange']

# %%
fruits[0]="blackberry"

# %%
print(fruits)
# Out:
# ['blackberry', 'guava', 'cherry']

# %%
fruits=["apple","banana","cherry"]
print(fruits)
# Out:
# ['apple', 'banana', 'cherry']

# %%
fruits.append("orange")

# %%
print(fruits)
# Out:
# ['apple', 'banana', 'cherry', 'orange']

# %%
fruits=["apple","banana","cherry"]
print(fruits)
# Out:
# ['apple', 'banana', 'cherry']

# %%
fruits[0]="lemon"

# %%
print(fruits)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c5ba58fe0871> in <cell line: 1>()
# ----> 1 print(fruits)
#
# NameError: name 'fruits' is not defined

# %%
fruits=["apple","banana","cherry"]
print(fruits)

# %%
fruits.pop(0)
# Out:
# 'banana'

# %%
print(fruits)
# Out:
# ['banana', 'cherry']
