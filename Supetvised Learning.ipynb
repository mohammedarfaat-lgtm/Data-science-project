# %%
# 1.  import the libraries

# %%
import pandas as pd
import numpy as np

# %%
# 2. Read csv file

# %%
df=pd.read_csv("house_prices.csv")

# %%
df
# Out:
#    SquareFootage   Price
# 0           1500  300000
# 1           1600  320000
# 2           1700  340000
# 3           1800  360000
# 4           1900  380000
# 5           2000  400000
# 6           2100  420000
# 7           2200  440000
# 8           2300  460000
# 9           2400  480000

# %%
df["SquareFootage"]
# Out:
# 0    1500
# 1    1600
# 2    1700
# 3    1800
# 4    1900
# 5    2000
# 6    2100
# 7    2200
# 8    2300
# 9    2400
# Name: SquareFootage, dtype: int64

# %%
df["Price"]
# Out:
# 0    300000
# 1    320000
# 2    340000
# 3    360000
# 4    380000
# 5    400000
# 6    420000
# 7    440000
# 8    460000
# 9    480000
# Name: Price, dtype: int64

# %%
df.head()
# Out:
#    SquareFootage   Price
# 0           1500  300000
# 1           1600  320000
# 2           1700  340000
# 3           1800  360000
# 4           1900  380000

# %%
df.tail()
# Out:
#    SquareFootage   Price
# 5           2000  400000
# 6           2100  420000
# 7           2200  440000
# 8           2300  460000
# 9           2400  480000

# %%
df.describe()
# Out:
#        SquareFootage          Price
# count      10.000000      10.000000
# mean     1950.000000  390000.000000
# std       302.765035   60553.007082
# min      1500.000000  300000.000000
# 25%      1725.000000  345000.000000
# 50%      1950.000000  390000.000000
# 75%      2175.000000  435000.000000
# max      2400.000000  480000.000000

# %%
import matplotlib.pyplot as plt
plt.scatter(df["SquareFootage"],df["Price"])

# %%
plt.scatter(df["SquareFootage"],df["Price"])
plt.xlabel("SquareFootage")
plt.ylabel("Price")
plt.title("House price vs SquareFootage")
plt.show()

# %%
#Feature

# %%
x=df[["SquareFootage"]]
x
# Out:
#    SquareFootage
# 0           1500
# 1           1600
# 2           1700
# 3           1800
# 4           1900
# 5           2000
# 6           2100
# 7           2200
# 8           2300
# 9           2400

# %%
x
# Out:
#    SquareFootage
# 0           1500
# 1           1600
# 2           1700
# 3           1800
# 4           1900
# 5           2000
# 6           2100
# 7           2200
# 8           2300
# 9           2400

# %%
y=df["Price"]
y
# Out:
# 0    300000
# 1    320000
# 2    340000
# 3    360000
# 4    380000
# 5    400000
# 6    420000
# 7    440000
# 8    460000
# 9    480000
# Name: Price, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.3,random_state=42)

# %%
x_train
# Out:
#    SquareFootage
# 0           1500
# 7           2200
# 2           1700
# 9           2400
# 4           1900
# 3           1800
# 6           2100

# %%
x_test
# Out:
#    SquareFootage
# 8           2300
# 1           1600
# 5           2000

# %%
y_train
# Out:
# 0    300000
# 7    440000
# 2    340000
# 9    480000
# 4    380000
# 3    360000
# 6    420000
# Name: Price, dtype: int64

# %%
y_test
# Out:
# 8    460000
# 1    320000
# 5    400000
# Name: Price, dtype: int64

# %%
# Display the shape of resulting data set
print(f"Training set size: {x_train.shape[0]} sample")
print(f"Testing set size:{x_test.shape[0]} sample")
# Out:
# Training set size: 7 sample
# Testing set size:3 sample

# %%
# creat the LinerRegression model
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array([460000., 320000., 400000.])

# %%
# Creat a scatter plolt of actual data points
plt.scatter(x_test,y_test,color="blue",label="actual")
# plot the regression line
plt.plot(x_test, y_pred, color="red",linewidth=2,label="predicted")
#add label and title
plt.xlabel("Square Footage")
plt.ylabel("Price")
plt.title("Square footage vs price(test set)")

#Add legend
plt.legend()
#Display the plot
plt.show()

# %%
from sklearn.metrics import mean_squared_error,r2_score
mse=mean_squared_error(y_test,y_pred)
mse
# Out:
# 0.0

# %%
# Calculate R-squared
r2=r2_score(y_test,y_pred)
r2
# Out:
# 1.0
