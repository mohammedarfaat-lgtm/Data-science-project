# %%
string="12121"
result=string.isalpha()
print(result)
# Out:
# False

# %%
string=""
result=string.isascii()
print(result)
# Out:
# True

# %%
string=""
result=string.isdecimal()
print(result)
# Out:
# True

# %%
string="   hello    "
result=string.rstrip()
print(result)
# Out:
#    hello

# %%
table=str.maketrans("aeiou","12345")
string="hello"
result=string.translate(table)
print(result)
# Out:
# h2ll4

# %%
string="hello world"
result=string.replace("world","universe")
print(result)
# Out:
# hello universe

# %%
string="hello world"
result=string.rfind("o")
print(result)
# Out:
# 7

# %%
string="hello world"
result=string.rjust(15)
print(result)
# Out:
#     hello world

# %%
string="    hello   "
result=string.rstrip()
print(result)
# Out:
#     hello

# %%
# prompt: hello world in paython

print("hello world")

# %%
table=str.maketrans("aeiou","12345")
string="hello"
result=string.translate(table)
print(result)
# Out:
# h2ll4

# %%
string="hello world"
result=string.replace("world","university")
print(result)
# Out:
# hello university

# %%
string= "hello world"
result=string.partition(" ")
print(result)
# Out:
# ('hello', ' ', 'world')

# %%
string=="hello world"
result=string.rindex("o")
print(result)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-80fd5a2b362f> in <cell line: 1>()
# ----> 1 string=="hello world"
#       2 result=string.rindex("o")
#       3 print(result)
#
# NameError: name 'string' is not defined

# %%
string="hello world"
result=string.rindex("o")

# %%
string="hello world"
