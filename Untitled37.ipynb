# %%
import datetime
time=datetime.time(10,14)
print(time)
# Out:
# 10:14:00

# %%
hour=time.hour
minute=time.minute
print("hour:",hour,"minute:",minute)
# Out:
# hour: 10 minute: 14

# %%
minute=time.minute
hour=time.hour
print("minute:",minute,"hour:",hour)
# Out:
# minute: 14 hour: 10

# %%
minute=time.minute
hour=time.hour
print("minute:",minute,"hour:",hour)
# Out:
# minute: 14 hour: 10

# %%
import datetime
time=datetime.time(10,30)
print(time)
# Out:
# 10:30:00

# %%
minute=time.minute
hour=time.hour
print("minute:",minute,"hour:",hour)
# Out:
# minute: 30 hour: 10

# %%
hour=time.hour
minute=time.minute
print("hour:",hour,"minute:",minute)

# %%
from datetime import datetime
current_time = datetime.now()
formatted_time = current_time.strftime("%I:%M %p")
print("Formatted time:", formatted_time)
# Out:
# Formatted time: 04:55 PM

# %%
from datetime import datetime
current_time=datetime.now()
formatted_time=current_time.strftime("%

# %%
from datetime import datetime

# Get the current time
current_time = datetime.now()

# Format the time as "Hour:Minute AM/PM"
formatted_time = current_time.strftime("%I:%M %p")

print("Current Time:", formatted_time)
# Out:
# Current Time: 09:37 PM
