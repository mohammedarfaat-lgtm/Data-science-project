# %%
age=25
print(age)
# Out:
# 25

# %%
is_student="true"
print(is_student)
# Out:
# true

# %%
Number=-3
print(Number)
# Out:
# -3

# %%
a=1000000
z=2020202
result=arfath+zama
print(result)
# Out:
# 30

# %%
a=1
z=20
result=a-z
print(result)
# Out:
# -19

# %%
a=2
b=2
print(a==b)
# Out:
# True

# %%
 * < > 0r equal no need of result
# Out:
#   File "<ipython-input-34-e5a74a9c5a55>", line 1
#     * < > 0r equal no need of result
#           ^
# SyntaxError: invalid decimal literal

# %%
is_student="true"
print(is_student)
# Out:
# true

# %%
a=5
b=5
print(a<=b)
# Out:
# True

# %%
my_string="my name is arfath"
first_char=my_string[4]
print(first_char)
# Out:
# a

# %%
name="hello world"
print(name[0:5])       string slicing
# Out:
#   File "<ipython-input-51-938db391f3d5>", line 2
#     print(name[0:5]) string slicing
#                      ^
# SyntaxError: invalid syntax

# %%
first_name="mohammed"
last_name="arfath"
full_name=first_name+" "+last_name
print(full_name)
# Out:
# mohammed arfath

# %%
string="maths"
result=string.upper()
print(result)
# Out:
# MATHS

# %%
first_name = "Arfath"
last_name = "Nagoor"
full_name = first_name + " " + last_name
print(full_name)
# Out:
# Arfath Nagoor

# %%
string="  hello  "
result=string.strip()
print(result)
# Out:
# hello

# %%
string="i lve my dog . because my dog is very good in bitting so i like my dog"
result=string.replace("dog" ,"cat")
print(result)
# Out:
# i lve my cat . because my cat is very good in bitting so i like my cat

# %%
string="i lve my cat . because my cat is very good in bitting so i like my cat"
print(len(string))
# Out:
# 70

# %%
string="my dog is good"
result=string.replace("dog","cat")
print(result)
# Out:
# my cat is good

# %%
string="data"
print(len(string))
# Out:
# 4

# %%
string=" arfath"*25
print(string)
# Out:
#  arfath arfath arfath arfath arfath arfath arfath arfath arfath arfath arfath arfath arfath arfath arfath arfath arfath arfath arfath arfath arfath arfath arfath arfath arfath

# %%
string="one,two,three"
result=string.rsplit(",")
print(result)
# Out:
# ['one', 'two', 'three']

# %%
list_string=["my dog is good", " my good is god"," my god is nice"]
single_string="".join(list_string)
print(single_string)
# Out:
# my dog is good my good is god my god is nice

# %%
name="mohammed arfath"
result="my name is {}".format(name)
print(result)
# Out:
# my name is mohammed arfath

# %%
book="xyz"
result="my name is {}".format(book)
print(result)
# Out:
# my name is xyz

# %%
name="arfath"
print(f"my name is {name}")
# Out:
# my name is arfath

# %%
name=['name "is" arfath']
print(name)
# Out:
# ['name "is" arfath']

# %%
string="learning python programming"
result=string.index("m")
print(result)
# Out:
# 22

# %%
string="my name is arfath"
char_list=list(string)
print(char_list)
# Out:
# ['m', 'y', ' ', 'n', 'a', 'm', 'e', ' ', 'i', 's', ' ', 'a', 'r', 'f', 'a', 't', 'h']

# %%
string="banana"
modified_string=string.replace("a","s")
print(modified_string)
# Out:
# bsnsns

# %%
original_string="my name is arfath"
modifide_string=original_string.replace("a", "")
print(modified_string)
# Out:
# bsnsns

# %%
original_string="my name is arfath"
modifide_string=original_string.replace("a", "")
print(modified_string)
# Out:
# bsnsns

# %%
a="my name is arfath"
modified_string=a.replace("a","")
print(modified_string)
# Out:
# my nme is rfth

# %%
str="radar"
if str==str[::-1]:
  print(str,"is a palindrome")
# Out:
# radar is a palindrome

# %%
string="mississippi"
count_p=string.count("p")
print(count_i)
# Out:
# 4

# %%
string="radar"
if string==string[::-1]:
  print(string, "'is a palindrome")
# Out:
# radar 'is a palindrome

# %%
string="radar"
if string==string[::-1]:
  print(string,"is a palindrome")
# Out:
# radar is a palindrome

# %%
string="civic"
if string==string[::-1]:
  print(string,"is a palindrome")
# Out:
# civic is a palindrome
