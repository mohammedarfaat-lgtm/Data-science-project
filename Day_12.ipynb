# %%
import pandas as pd

# %%
#

# %%
data={
    "name":["alice","bob","charli","david"],
    "age":[25,30,35,40]
}

# %%
display(data)
# Out:
# {'name': ['alice', 'bob', 'charli', 'david'], 'age': [25, 30, 35, 40]}

# %%
df=pd.DataFrame(data)
display(df)
# Out:
#      name  age
# 0   alice   25
# 1     bob   30
# 2  charli   35
# 3   david   40

# %%
# two table data sturcture

# %%
df.head()
# Out:
#      name  age
# 0   alice   25
# 1     bob   30
# 2  charli   35
# 3   david   40

# %%
df.head(2)
# Out:
#     name  age
# 0  alice   25
# 1    bob   30

# %%
df.head(3)
# Out:
#      name  age
# 0   alice   25
# 1     bob   30
# 2  charli   35

# %%
df.tail(2)
# Out:
#      name  age
# 2  charli   35
# 3   david   40

# %%
df["name"]
# Out:
# 0     alice
# 1       bob
# 2    charli
# 3     david
# Name: name, dtype: object

# %%
df["age"]
# Out:
# 0    25
# 1    30
# 2    35
# 3    40
# Name: age, dtype: int64

# %%
df[["name","age"]]
# Out:
#      name  age
# 0   alice   25
# 1     bob   30
# 2  charli   35
# 3   david   40

# %%
df[df["age"]>30]
# Out:
#      name  age
# 2  charli   35
# 3   david   40

# %%
df["grade"]=["a","b","a","c"]

# %%
df
# Out:
#      name  age grade
# 0   alice   25     a
# 1     bob   30     b
# 2  charli   35     a
# 3   david   40     c

# %%
data={
    "name":["manju","kumar","suresh"],
    "age":[30,40,50]
}

# %%
display(data)
# Out:
# {'name': ['manju', 'kumar', 'suresh'], 'age': [30, 40, 50]}

# %%
df.drop("grade",axis=1,inplace=True)

# %%
df
# Out:
#      name  age
# 0   alice   25
# 1     bob   30
# 2  charli   35
# 3   david   40

# %%
import pandas as pd
data = {'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve', 'Frank', 'Grace', 'Hannah', 'Isaac', 'Jack'],
        'Age': [25, 30, 35, 40, 45, 50, 55, 60, 65, 70],
        'Gender': ['F', 'M', 'M', 'M', 'F', 'M', 'F', 'F', 'M', 'M'],
        'Salary': [50000, 60000, 70000, 80000, 90000, 100000, 110000, 120000, 130000, 140000],
        'Department': ['HR', 'Finance', 'IT', 'Finance', 'HR', 'IT', 'HR', 'IT', 'Finance', 'HR']}

df = pd.DataFrame(data)
display(df)
# Out:
#       Name  Age Gender  Salary Department
# 0    Alice   25      F   50000         HR
# 1      Bob   30      M   60000    Finance
# 2  Charlie   35      M   70000         IT
# 3    David   40      M   80000    Finance
# 4      Eve   45      F   90000         HR
# 5    Frank   50      M  100000         IT
# 6    Grace   55      F  110000         HR
# 7   Hannah   60      F  120000         IT
# 8    Isaac   65      M  130000    Finance
# 9     Jack   70      M  140000         HR

# %%
filterdage=df[df["Age"]>40]
display(filterdage)
# Out:
#      Name  Age Gender  Salary Department
# 4     Eve   45      F   90000         HR
# 5   Frank   50      M  100000         IT
# 6   Grace   55      F  110000         HR
# 7  Hannah   60      F  120000         IT
# 8   Isaac   65      M  130000    Finance
# 9    Jack   70      M  140000         HR

# %%
filtered_df2=df[(df["Gender"]=="F") & (df["Department"]=="HR")]
display(filtered_df2)
# Out:
#     Name  Age Gender  Salary Department
# 0  Alice   25      F   50000         HR
# 4    Eve   45      F   90000         HR
# 6  Grace   55      F  110000         HR

# %%
filtered_df2=df[(df["Gender"]=="M") & (df["Department"]=="HR")]
display(filtered_df2)
# Out:
#    Name  Age Gender  Salary Department
# 9  Jack   70      M  140000         HR

# %%
df["Age"]>40
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# Name: Age, dtype: bool

# %%
filtered_df3=df[df["Salary"].between(60000,110000)]
display(filtered_df3)
# Out:
#       Name  Age Gender  Salary Department
# 1      Bob   30      M   60000    Finance
# 2  Charlie   35      M   70000         IT
# 3    David   40      M   80000    Finance
# 4      Eve   45      F   90000         HR
# 5    Frank   50      M  100000         IT
# 6    Grace   55      F  110000         HR

# %%
filtered_df4=df[df["Name"].str.startswith("A") | df["Name"].str.endswith("e")]
display(filtered_df4)
# Out:
#       Name  Age Gender  Salary Department
# 0    Alice   25      F   50000         HR
# 2  Charlie   35      M   70000         IT
# 4      Eve   45      F   90000         HR
# 6    Grace   55      F  110000         HR

# %%
#Task given by sir

# %%
avg_salary=df["Salary"].mean()
avg_salary
# Out:
# np.float64(95000.0)

# %%
number_of_employees=df["Name"].count()
number_of_employees
# Out:
# np.int64(10)

# %%
highest_salary=df["Salary"].max()
display(highest_salary)
# Out:
# 140000

# %%
highest_salary=df["Salary"].max()
highest_salary
# Out:
# 140000

# %%
d=df["Salary"].sum()
d
# Out:
# np.int64(950000)

# %%
longest_name_employee=df["Name"].str.len().idxmax()
display(longest_name_employee)
# Out:
# 2

# %%
name2=df["Name"].str.len()
max_length=name2.max()
longest_name_employee=df[name2==max_length]
display(longest_name_employee)
# Out:
#       Name  Age Gender  Salary Department
# 2  Charlie   35      M   70000         IT

# %%
# which departement has higest average salary

# %%
department_highest_avg_salary=df.groupby("Department")["Salary"].mean()
department_highest_avg_salary
# Out:
# Department
# Finance    90000.000000
# HR         97500.000000
# IT         96666.666667
# Name: Salary, dtype: float64

# %%
department_highest_avg_salary=df.groupby("Department")["Salary"].mean().max()
department_highest_avg_salary
# Out:
# 97500.0

# %%
#nWhich employee has longest name

# %%
longest_name=df["Name"]
print(longest_name)
# Out:
# 0      Alice
# 1        Bob
# 2    Charlie
# 3      David
# 4        Eve
# 5      Frank
# 6      Grace
# 7     Hannah
# 8      Isaac
# 9       Jack
# Name: Name, dtype: object

# %%
longest_name=df["Name"].apply(len)
print(longest_name)
# Out:
# 0    5
# 1    3
# 2    7
# 3    5
# 4    3
# 5    5
# 6    5
# 7    6
# 8    5
# 9    4
# Name: Name, dtype: int64

# %%
longest_name=df["Name"].apply(len).idxmax()
print(longest_name)
# Out:
# 2

# %%
longest_name=df.loc[df["Name"].apply(len).idxmax(),"Name"]
print(longest_name)
# Out:
# Charlie

# %%
longest_name=df["Name"].apply(len).idxmax(),"Name"
print(longest_name)
# Out:
# (2, 'Name')

# %%
import pandas as pd
data = {'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve', 'Frank', 'Grace', 'Hannah', 'Isaac', 'Jack'],
        'Age': [25, 30, 35, 40, 45, 50, 55, 60, 65, 70],
        'Gender': ['F', 'M', 'M', 'M', 'F', 'M', 'F', 'F', 'M', 'M'],
        'Salary': [50000, 60000, 70000, 80000, 90000, 100000, 110000, 120000, 130000, 140000],
        'Department': ['HR', 'Finance', 'IT', 'Finance', 'HR', 'IT', 'HR', 'IT', 'Finance', 'HR']}

df = pd.DataFrame(data)

# %%
print(df)
# Out:
#       Name  Age Gender  Salary Department
# 0    Alice   25      F   50000         HR
# 1      Bob   30      M   60000    Finance
# 2  Charlie   35      M   70000         IT
# 3    David   40      M   80000    Finance
# 4      Eve   45      F   90000         HR
# 5    Frank   50      M  100000         IT
# 6    Grace   55      F  110000         HR
# 7   Hannah   60      F  120000         IT
# 8    Isaac   65      M  130000    Finance
# 9     Jack   70      M  140000         HR

# %%
print(df.head())
print(df.tail())
print(df.shape)
print(df.columns)
# Out:
#       Name  Age Gender  Salary Department
# 0    Alice   25      F   50000         HR
# 1      Bob   30      M   60000    Finance
# 2  Charlie   35      M   70000         IT
# 3    David   40      M   80000    Finance
# 4      Eve   45      F   90000         HR
#      Name  Age Gender  Salary Department
# 5   Frank   50      M  100000         IT
# 6   Grace   55      F  110000         HR
# 7  Hannah   60      F  120000         IT
# 8   Isaac   65      M  130000    Finance
# 9    Jack   70      M  140000         HR
# (10, 5)
# Index(['Name', 'Age', 'Gender', 'Salary', 'Department'], dtype='object')

# %%
print(df.shape)
# Out:
# (10, 5)

# %%
print(df.columns)
# Out:
# Index(['Name', 'Age', 'Gender', 'Salary', 'Department'], dtype='object')

# %%
print(df["Name"])
# Out:
# 0      Alice
# 1        Bob
# 2    Charlie
# 3      David
# 4        Eve
# 5      Frank
# 6      Grace
# 7     Hannah
# 8      Isaac
# 9       Jack
# Name: Name, dtype: object

# %%
print(df[["Name","Age"]])
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35
# 3    David   40
# 4      Eve   45
# 5    Frank   50
# 6    Grace   55
# 7   Hannah   60
# 8    Isaac   65
# 9     Jack   70

# %%
print(df.loc[0])
# Out:
# Name          Alice
# Age              25
# Gender            F
# Salary        50000
# Department       HR
# Name: 0, dtype: object

# %%
print(df.loc[1])
# Out:
# Name              Bob
# Age                30
# Gender              M
# Salary          60000
# Department    Finance
# Name: 1, dtype: object

# %%
print(df.loc[9])
# Out:
# Name            Jack
# Age               70
# Gender             M
# Salary        140000
# Department        HR
# Name: 9, dtype: object

# %%
print(df[df["Age"]>50])
# Out:
#      Name  Age Gender  Salary Department
# 6   Grace   55      F  110000         HR
# 7  Hannah   60      F  120000         IT
# 8   Isaac   65      M  130000    Finance
# 9    Jack   70      M  140000         HR

# %%
print(df.query("Age>50"))
# Out:
#      Name  Age Gender  Salary Department
# 6   Grace   55      F  110000         HR
# 7  Hannah   60      F  120000         IT
# 8   Isaac   65      M  130000    Finance
# 9    Jack   70      M  140000         HR

# %%
print(df.isnull())
# Out:
#     Name    Age  Gender  Salary  Department
# 0  False  False   False   False       False
# 1  False  False   False   False       False
# 2  False  False   False   False       False
# 3  False  False   False   False       False
# 4  False  False   False   False       False
# 5  False  False   False   False       False
# 6  False  False   False   False       False
# 7  False  False   False   False       False
# 8  False  False   False   False       False
# 9  False  False   False   False       False

# %%
df.isnull()
# Out:
#     Name    Age  Gender  Salary  Department
# 0  False  False   False   False       False
# 1  False  False   False   False       False
# 2  False  False   False   False       False
# 3  False  False   False   False       False
# 4  False  False   False   False       False
# 5  False  False   False   False       False
# 6  False  False   False   False       False
# 7  False  False   False   False       False
# 8  False  False   False   False       False
# 9  False  False   False   False       False

# %%
df.dropna()
# Out:
#       Name  Age Gender  Salary Department
# 0    Alice   25      F   50000         HR
# 1      Bob   30      M   60000    Finance
# 2  Charlie   35      M   70000         IT
# 3    David   40      M   80000    Finance
# 4      Eve   45      F   90000         HR
# 5    Frank   50      M  100000         IT
# 6    Grace   55      F  110000         HR
# 7   Hannah   60      F  120000         IT
# 8    Isaac   65      M  130000    Finance
# 9     Jack   70      M  140000         HR

# %%
df.describe()
# Out:
#              Age         Salary
# count  10.000000      10.000000
# mean   47.500000   95000.000000
# std    15.138252   30276.503541
# min    25.000000   50000.000000
# 25%    36.250000   72500.000000
# 50%    47.500000   95000.000000
# 75%    58.750000  117500.000000
# max    70.000000  140000.000000

# %%
import pandas as pd
data = {'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve', 'Frank', 'Grace', 'Hannah', 'Isaac', 'Jack'],
        'Age': [25, 25, 35, 40, 45, 50, 55, 60, 65, 70],
        'Gender': ['F', 'M', 'M', 'M', 'F', 'M', 'F', 'F', 'M', 'M'],
        'Salary': [50000, 60000, 70000, 80000, 90000, 100000, 110000, 120000, 130000, 140000],
        'Department': ['HR', 'Finance', 'IT', 'Finance', 'HR', 'IT', 'HR', 'IT', 'Finance', 'HR']}

df = pd.DataFrame(data)

# %%
print(df["Age"].value_counts())
# Out:
# Age
# 25    2
# 35    1
# 40    1
# 45    1
# 50    1
# 55    1
# 60    1
# 65    1
# 70    1
# Name: count, dtype: int64

# %%
groyuped_df=df.groupby("Department")["Salary"].mean()
display(groyuped_df)
# Out:
# Department
# Finance    90000.000000
# HR         97500.000000
# IT         96666.666667
# Name: Salary, dtype: float64

# %%
groyuped_df=df.groupby("Department")["Age"].mean()
display(groyuped_df)
# Out:
# Department
# Finance    43.333333
# HR         48.750000
# IT         48.333333
# Name: Age, dtype: float64

# %%
print(df.sort_values(by="Age",ascending=True))
# Out:
#       Name  Age Gender  Salary Department
# 0    Alice   25      F   50000         HR
# 1      Bob   25      M   60000    Finance
# 2  Charlie   35      M   70000         IT
# 3    David   40      M   80000    Finance
# 4      Eve   45      F   90000         HR
# 5    Frank   50      M  100000         IT
# 6    Grace   55      F  110000         HR
# 7   Hannah   60      F  120000         IT
# 8    Isaac   65      M  130000    Finance
# 9     Jack   70      M  140000         HR

# %%
print(df.sort_values(by="Age",ascending=False))
# Out:
#       Name  Age Gender  Salary Department
# 9     Jack   70      M  140000         HR
# 8    Isaac   65      M  130000    Finance
# 7   Hannah   60      F  120000         IT
# 6    Grace   55      F  110000         HR
# 5    Frank   50      M  100000         IT
# 4      Eve   45      F   90000         HR
# 3    David   40      M   80000    Finance
# 2  Charlie   35      M   70000         IT
# 1      Bob   25      M   60000    Finance
# 0    Alice   25      F   50000         HR

# %%
def double_age(x):
  return x+2
print(df["Age"].apply(double_age))
# Out:
# 0    27
# 1    27
# 2    37
# 3    42
# 4    47
# 5    52
# 6    57
# 7    62
# 8    67
# 9    72
# Name: Age, dtype: int64

# %%
def salary_incriment(x):
  return x*0.05
print(df["Salary"].apply(salary_incriment))
# Out:
# 0    2500.0
# 1    3000.0
# 2    3500.0
# 3    4000.0
# 4    4500.0
# 5    5000.0
# 6    5500.0
# 7    6000.0
# 8    6500.0
# 9    7000.0
# Name: Salary, dtype: float64

# %%
df2=pd.DataFrame({"Department":["HR","Finance","IT"],"location":["Bangalore","mumbai","chennai"]})
merged_df=pd.merge(df,df2,on="Department")
print(merged_df)
# Out:
#       Name  Age Gender  Salary Department   location
# 0    Alice   25      F   50000         HR  Bangalore
# 1      Bob   25      M   60000    Finance     mumbai
# 2  Charlie   35      M   70000         IT    chennai
# 3    David   40      M   80000    Finance     mumbai
# 4      Eve   45      F   90000         HR  Bangalore
# 5    Frank   50      M  100000         IT    chennai
# 6    Grace   55      F  110000         HR  Bangalore
# 7   Hannah   60      F  120000         IT    chennai
# 8    Isaac   65      M  130000    Finance     mumbai
# 9     Jack   70      M  140000         HR  Bangalore

# %%
# task given by sir

# %%
import pandas as pd
data = {'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve', 'Frank', 'Grace', 'Hannah', 'Isaac', 'Jack'],
        'Age': [25, 25, 35, 40, 45, 50, 55, 60, 65, 70],
        'Gender': ['F', 'M', 'M', 'M', 'F', 'M', 'F', 'F', 'M', 'M'],
        'Salary': [50000, 60000, 70000, 80000, 90000, 100000, 110000, 120000, 130000, 140000],
        'Department': ['HR', 'Finance', 'IT', 'Finance', 'HR', 'IT', 'HR', 'IT', 'Finance', 'HR']}

df = pd.DataFrame(data)
df
# Out:
#       Name  Age Gender  Salary Department
# 0    Alice   25      F   50000         HR
# 1      Bob   25      M   60000    Finance
# 2  Charlie   35      M   70000         IT
# 3    David   40      M   80000    Finance
# 4      Eve   45      F   90000         HR
# 5    Frank   50      M  100000         IT
# 6    Grace   55      F  110000         HR
# 7   Hannah   60      F  120000         IT
# 8    Isaac   65      M  130000    Finance
# 9     Jack   70      M  140000         HR

# %%
avg_salary=df["Salary"].mean()
display(avg_salary)
# Out:
# np.float64(95000.0)

# %%
no_of_employee=df["Name"].count()
display(no_of_employee)
# Out:
# np.int64(10)

# %%
highest_salary=df["Salary"].max()
display(highest_salary)
# Out:
# 140000

# %%
total_salary=df["Salary"].sum()
display(total_salary)
# Out:
# np.int64(950000)

# %%
filter_df_2=df[(df["Gender"]=="M") & (df["Department"]=="IT")]
display(filter_df_2)
# Out:
#       Name  Age Gender  Salary Department
# 2  Charlie   35      M   70000         IT
# 5    Frank   50      M  100000         IT

# %%
highest_avg_salary=df.groupby("Department")["Salary"].mean()
display(highest_avg_salary)
# Out:
# Department
# Finance    90000.000000
# HR         97500.000000
# IT         96666.666667
# Name: Salary, dtype: float64

# %%
import pandas as pd
longest_name=df.loc[df["Name"].apply(len).idxmax(),"Name"]
display(longest_name)
# Out:
# 'Charlie'

# %%
department_highest_avg_salary=df.groupby("Department")["Salary"].max()
department_highest_avg_salary
# Out:
# Department
# Finance    130000
# HR         140000
# IT         120000
# Name: Salary, dtype: int64

# %%
department_highest_avg_salary=df.groupby("Department")["Salary"].min()
department_highest_avg_salary
# Out:
# Department
# Finance    60000
# HR         50000
# IT         70000
# Name: Salary, dtype: int64

# %%
# 8 or maximun and minum salar in Finance

# %%
df = pd.DataFrame(data)

# Filter for Finance department# obtained from cht chatgpt
finance_salaries = df[df['Department'] == 'Finance']['Salary']

# Get minimum and maximum salary
min_salary = finance_salaries.min()
max_salary = finance_salaries.max()

print(max_salary,
      min_salary)
# Out:
# 130000 60000

# %%
df = pd.DataFrame(data)

# Filter for Finance department# obtained from cht chatgpt
finance_salaries = df[df['Department'] == 'Finance']['Salary']

# Get minimum and maximum salary
min_salary = finance_salaries.min()
max_salary = finance_salaries.max()

print(f"Finance Department Salary Range:\nMinimum Salary: ₹{min_salary}\nMaximum Salary: ₹{max_salary}")
# Out:
# Finance Department Salary Range:
# Minimum Salary: ₹60000
# Maximum Salary: ₹130000

# %%
a=df[df["Department"]=="Finance"]["Salary"]
m=a.max
n=a.min
print(a)
# Out:
# 1     60000
# 3     80000
# 8    130000
# Name: Salary, dtype: int64

# %%
#How many unique departments are there in the dataset?

# %%
a=df["Department"].unique()
display(a)
# Out:
# array(['HR', 'Finance', 'IT'], dtype=object)

# %%
lowest_salary=df.groupby("Department")["Salary"].min().idxmin()
lowest_salary
# Out:
# 'HR'

# %%
# 10) which employee has the lowest salary?

# %%
lowest_salary=df.loc[df["Name"].idxmin()]
display(lowest_salary)
# Out:
# Name          Alice
# Age              25
# Gender            F
# Salary        50000
# Department       HR
# Name: 0, dtype: object

# %%
#11 pending

# %%
# 12) Which department has the highest total salary expenditure

# %%
department_salary = df.groupby('Department')['Salary'].sum()

# Find the department with the highest total salary
highest_dept = department_salary.idxmax()
highest_total = department_salary.max()

# Display result
print("Department with highest total salary expenditure:")
print("Department:", highest_dept)
print("Total Salary Expenditure:", highest_total)
# Out:
# Department with highest total salary expenditure:
# Department: HR
# Total Salary Expenditure: 390000

# %%
# 13) How many employees are there in each department

# %%
num_of_employee=df.groupby("Department")["Name"].count()
print(num_of_employee)
# Out:
# Department
# Finance    3
# HR         4
# IT         3
# Name: Name, dtype: int64

# %%
# 14) What is the average salary for male and female employees

# %%
avg_male_salary=df.groupby("Gender")["Salary"].mean()
print(avg_male_salary)
# Out:
# Gender
# F    92500.000000
# M    96666.666667
# Name: Salary, dtype: float64

# %%
#15 Which employee has the highest salary in the IT department
highest_salay=df.loc[df["Department"]=="IT"]
highest_salary=highest_salay.loc[highest_salay["Salary"].idxmax()]
print(highest_salary)
# Out:
# Name          Hannah
# Age               60
# Gender             F
# Salary        120000
# Department        IT
# Name: 7, dtype: object

# %%
#16) What is the average age of employees in the HR department
avg_age_by_department = df.groupby("Department")["Age"].mean()
print(avg_age_by_department)
# Out:
# Department
# Finance    43.333333
# HR         48.750000
# IT         48.333333
# Name: Age, dtype: float64

# %%
# 17)Which department has the highest number of employees above 35 years old
employees_above_35 = df[df["Age"] > 35]
department_counts = employees_above_35.groupby("Department").size()
print(department_counts)
# Out:
# Department
# Finance    2
# HR         3
# IT         2
# dtype: int64

# %%
#18) How many employees have a salary above the average salary
avg_salary = df["Salary"].mean()
employees_above_avg_salary = df[df["Salary"] > avg_salary].shape[0]
print(employees_above_avg_salary)
# Out:
# 5

# %%
#19) Which department has the highest salary range (difference between the highest and lowest salary)
dep_highest_salary_range=df.groupby("Department")["Salary"].max()
dep_highest_salary_range
# Out:
# Department
# Finance    130000
# HR         140000
# IT         120000
# Name: Salary, dtype: int64

# %%
#20)What is the average salary for employees whose name starts with 'A
Name_start_with_A=df[df["Name"].str.startswith("A")]["Salary"].mean()
print(Name_start_with_A)
# Out:
# 50000.0

# %%
#task(2)

# %%
#) Read a CSV file named 'data.csv' into a Pandas DataFrame and display the first 5 rows
try:
    df = pd.read_csv('data.csv')
    display(df.head())
except FileNotFoundError:
    print("Error: 'data.csv' not found. Please make sure the file is in the correct directory.")
# Out:
# Error: 'data.csv' not found. Please make sure the file is in the correct directory.

# %%
import matplotlib.pyplot as plt

# %%
x=[1,2,3,4,5]
y=[10,20,25,30,35]

# %%
plt.plot(x,y)

# %%
plt.xlabel("X-axis label")
# Out:
# Text(0.5, 0, 'X-axis label')

# %%
plt.ylabel("Y_axis label")
# Out:
# Text(0, 0.5, 'Y_axis label')

# %%
plt.xlabel("X-axis")
plt.ylabel("Y-Axis")
plt.title("employee management")
plt.show()

# %%
import matplotlib.pyplot as plt

# %%
labels=["alice","bob","charle","david"]
salaries=[10000,60000,70000,55000]

# %%
plt.figure(figsize=(2,2))
plt.pie(salaries, labels=labels)
plt.title("Employee Salaries")
plt.show()

# %%
labes=["Alice","bob","charlie","david"]
salaries=[50000,60000,70000,55000]
plt.figure(figsize=(8,6))
plt.pie(salaries,labels=labels,autopct="%1.0f%%",startangle=90)
plt.show()

# %%
labels=["A","B","C","D"]
sizes=[10,20,30,40]
explode=(0,0.1,0,0.2)
plt.figure(figsize=(8,6))
plt.pie(sizes,labels=labels,explode=explode,autopct="%1.0f%%",startangle=90)
plt.title("Explode pie chart")
plt.show()

# %%
labels=["A","B","C","D"]
sizes=[25,35,20,20]

plt.figure(figsize=(8,6))
plt.pie(sizes,labels=labels,autopct="%1.1f%%",startangle=90,wedgeprops=dict(width=0.4))
plt.title("Donutchart")
plt.show()

# %%
# !pip install python-docx
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.0/253.0 kB 5.1 MB/s eta 0:00:00
# ...
