# %%
fruits=["apple","banana","cherry"]
print(fruits)
# Out:
# ['apple', 'banana', 'cherry']

# %%
fruits=["apple","banana","cherry"]
print(fruits)
# Out:
# ['apple', 'banana', 'cherry']

# %%
more_fruits=["mango","blackbreey","pineapple"]
print(more_fruits)
# Out:
# ['mango', 'blackbreey', 'pineapple']

# %%
fruits.pop(2)
print(fruits)
# Out:
# ['apple', 'banana']

# %%
fruits=["apple","banana","cherry"]
print(fruits)
# Out:
# ['apple', 'banana', 'cherry']

# %%
more_fruits=["mango","blackbreey","pineapple"]
print(more_fruits)
# Out:
# ['mango', 'blackbreey', 'pineapple']

# %%
all_fruits=["badam","halwa", "kaju"]
print(all_fruits)
# Out:
# ['badam', 'halwa', 'kaju']

# %%
print(fruits)
print(more_fruits)
print(all_fruits)
# Out:
# ['apple', 'banana', 'cherry']
# ['mango', 'blackbreey', 'pineapple']
# ['badam', 'halwa', 'kaju']

# %%
fruits.extend(more_fruits)
fruits.extend(all_fruits)
print(fruits)
# Out:
# ['apple', 'banana', 'cherry', 'mango', 'blackbreey', 'pineapple', 'badam', 'halwa', 'kaju', 'mango', 'blackbreey', 'pineapple', 'badam', 'halwa', 'kaju', 'mango', 'blackbreey', 'pineapple', 'badam', 'halwa', 'kaju']

# %%
fruits=['apple', 'banana', 'cherry', 'mango', 'blackbreey', 'pineapple', 'badam', 'halwa', 'kaju', 'mango', 'blackbreey', 'pineapple', 'badam', 'halwa', 'kaju']
print(fruits)
# Out:
# ['apple', 'banana', 'cherry', 'mango', 'blackbreey', 'pineapple', 'badam', 'halwa', 'kaju', 'mango', 'blackbreey', 'pineapple', 'badam', 'halwa', 'kaju']

# %%
fruits.pop(fruits)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-8fdb078bcc93> in <cell line: 1>()
# ----> 1 fruits.pop(fruits)
#
# TypeError: 'list' object cannot be interpreted as an integer

# %%
print(fruits)
print(more_fruits)
# Out:
# ['apple', 'banana', 'cherry']
# ['mango', 'blackbreey', 'pineapple']

# %%
fruits.extend(more_fruits)

# %%
print(fruits)
# Out:
# ['apple', 'banana', 'cherry', 'mango', 'blackbreey', 'pineapple']

# %%
all_fruits=["badam","halwa", "kaju"]
print(all_fruits)
# Out:
# ['badam', 'halwa', 'kaju']

# %%
print(fruits)
print(more_fruits)
print(all_fruits)
# Out:
# ['apple', 'banana', 'cherry', 'mango', 'blackbreey', 'pineapple', 'mango', 'blackbreey', 'pineapple']
# ['mango', 'blackbreey', 'pineapple']
# ['badam', 'halwa', 'kaju']

# %%
fruits.extend(more_fruits)
fruits.extend(all_fruits)

# %%
print(fruits)
# Out:
# ['apple', 'banana', 'cherry', 'mango', 'blackbreey', 'pineapple', 'mango', 'blackbreey', 'pineapple', 'mango', 'blackbreey', 'pineapple', 'badam', 'halwa', 'kaju', 'mango', 'blackbreey', 'pineapple', 'badam', 'halwa', 'kaju']

# %%
print(len(all_fruits))
# Out:
# 3

# %%
print(all_fruits)
# Out:
# ['badam', 'halwa', 'kaju']

# %%
fruits=['apple', 'banana', 'cherry', 'mango', 'blackbreey', 'pineapple', 'mango', 'blackbreey', 'pineapple', 'mango', 'blackbreey', 'pineapple', 'badam', 'halwa', 'kaju', 'mango', 'blackbreey', 'pineapple', 'badam', 'halwa', 'kaju']
print(fruits)
# Out:
# ['apple', 'banana', 'cherry', 'mango', 'blackbreey', 'pineapple', 'mango', 'blackbreey', 'pineapple', 'mango', 'blackbreey', 'pineapple', 'badam', 'halwa', 'kaju', 'mango', 'blackbreey', 'pineapple', 'badam', 'halwa', 'kaju']

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-87018ec2a884> in <cell line: 1>()
# ----> 1 fruits.pop(more_fruits)
#
# TypeError: 'list' object cannot be interpreted as an integer

# %%
fruits=["apple","mango","sitafal"]
print(fruits)
# Out:
# ['apple', 'mango', 'sitafal']

# %%
morefruits=["orange","pineapple","badam"]
print(morefruits)
# Out:
# ['orange', 'pineapple', 'badam']

# %%
allfruits=["anaar","halwa","banana"]
print(allfruits)
# Out:
# ['anaar', 'halwa', 'banana']

# %%
fruits.extend(morefruits)
fruits.extend(allfruits)
print(fruits)
# Out:
# ['apple', 'mango', 'sitafal', 'orange', 'pineapple', 'badam', 'anaar', 'halwa', 'banana']

# %%
print(fruits)
# Out:
# ['apple', 'mango', 'sitafal', 'orange', 'pineapple', 'badam', 'anaar', 'halwa', 'banana']

# %%
all_fruits=['paple', 'mango', 'sitafal', 'orange', 'pineapple', 'badam', 'anaar', 'halwa', 'banana']
print(all_fruits[0:3])
# Out:
# ['apple', 'mango', 'sitafal']

# %%
fruits=['apaple', 'mango', "apple","apple",'sitafal', 'orange', 'pineapple', 'badam', 'anaar', 'halwa', 'banana']
fruits.sort()
print(fruits)
# Out:
# ['anaar', 'badam', 'banana', 'halwa', 'mango', 'orange', 'paple', 'pineapple', 'sitafal']

# %%
fruits=['apaple', 'mango', "apple","apple",'sitafal', 'orange', 'pineapple', 'badam', 'anaar', 'halwa', 'banana']
print
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-73-b47d473c5a7a> in <cell line: 2>()
#       1 fruits=['apaple', 'mango', "apple","apple",'sitafal', 'orange', 'pineapple', 'badam', 'anaar', 'halwa', 'banana']
# ----> 2 print(fruits.count["apple"])
#
# TypeError: 'builtin_function_or_method' object is not subscriptable
