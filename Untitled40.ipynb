# %%
from io import BytesIO
from subprocess import run

# Convert .doc to .docx using LibreOffice (if available)
converted_file_path = "/mnt/data/mohammed_arfath.docx"
run(["soffice", "--headless", "--convert-to", "docx", "--outdir", "/mnt/data", file_path])

# Load the converted .docx file
doc = Document(converted_file_path)

# Find the "WORK EXPIRIENCE" section and update it
for para in doc.paragraphs:
    if "WORK EXPIRIENCE" in para.text:
        index = doc.paragraphs.index(para) + 1  # Next line contains experience details
        doc.paragraphs[index].text = (
            "· 2 years of solid teaching experience in the ICSE board at Mile Stone International School.\n"
            "· 1 year working experience as Assistant Teacher in Naunihall Central School Bhatkal."
        )
        break

# Save the updated document
updated_file_path = "/mnt/data/mohammed_arfath_updated.docx"
doc.save(updated_file_path)

# Provide the download link
updated_file_path
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e067601c4a4a> in <cell line: 0>()
#       4 # Convert .doc to .docx using LibreOffice (if available)
#       5 converted_file_path = "/mnt/data/mohammed_arfath.docx"
# ----> 6 run(["soffice", "--headless", "--convert-to", "docx", "--outdir", "/mnt/data", file_path])
#       7
#       8 # Load the converted .docx file
#
# NameError: name 'file_path' is not defined

# %%
from io import BytesIO
from subprocess import run
from docx import Document # Added import statement for Document

# Convert .doc to .docx using LibreOffice (if available)
converted_file_path = "/mnt/data/mohammed_arfath.docx"
file_path = "/mnt/data/mohammed_arfath.doc"  # Define file_path with the input file path
run(["soffice", "--headless", "--convert-to", "docx", "--outdir", "/mnt/data", file_path])

# Load the converted .docx file
doc = Document(converted_file_path)

# Find the "WORK EXPIRIENCE" section and update it
for para in doc.paragraphs:
    if "WORK EXPIRIENCE" in para.text:
        index = doc.paragraphs.index(para) + 1  # Next line contains experience details
        doc.paragraphs[index].text = (
            "· 2 years of solid teaching experience in the ICSE board at Mile Stone International School.\n"
            "· 1 year working experience as Assistant Teacher in Naunihall Central School Bhatkal."
        )
        break

# Save the updated document
updated_file_path = "/mnt/data/mohammed_arfath_updated.docx"
doc.save(updated_file_path)

# Provide the download link
updated_file_path
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-1f1a5671d772> in <cell line: 0>()
#       1 from io import BytesIO
#       2 from subprocess import run
# ----> 3 from docx import Document # Added import statement for Document
#       4
#       5 # Convert .doc to .docx using LibreOffice (if available)
#
# ModuleNotFoundError: No module named 'docx'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from io import BytesIO
from subprocess import run

# Convert .doc to .docx using LibreOffice (if available)
converted_file_path = "/mnt/data/mohammed_arfath.docx"
run(["soffice", "--headless", "--convert-to", "docx", "--outdir", "/mnt/data", file_path])

# Load the converted .docx file
doc = Document(converted_file_path)

# Find the "WORK EXPIRIENCE" section and update it
for para in doc.paragraphs:
    if "WORK EXPIRIENCE" in para.text:
        index = doc.paragraphs.index(para) + 1  # Next line contains experience details
        doc.paragraphs[index].text = (
            "· 2 years of solid teaching experience in the ICSE board at Mile Stone International School.\n"
            "· 1 year working experience as Assistant Teacher in Naunihall Central School Bhatkal."
        )
        break

# Save the updated document
updated_file_path = "/mnt/data/mohammed_arfath_updated.docx"
doc.save(updated_file_path)

# Provide the download link
updated_file_path
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-e067601c4a4a> in <cell line: 0>()
#       4 # Convert .doc to .docx using LibreOffice (if available)
#       5 converted_file_path = "/mnt/data/mohammed_arfath.docx"
# ----> 6 run(["soffice", "--headless", "--convert-to", "docx", "--outdir", "/mnt/data", file_path])
#       7
#       8 # Load the converted .docx file
#
# NameError: name 'file_path' is not defined
