# %%
person = {"name":"alice","age":25}
result="my name is {name} and i am {age} year old.".format_map(person)
print(result)
# Out:
# my name is alice and i am 25 year old.

# %%
string="hello world"
result=string.index("o")
print(result)
# Out:
# 4

# %%
string="hello world"
result=string.index("h")
print(result)
# Out:
# 0

# %%
string="516315614"
result=string.isnum()
print(result)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-25a7f190290a> in <cell line: 2>()
#       1 string="516315614"
# ----> 2 result=string.isnum()
#       3 print(result)
#
# AttributeError: 'str' object has no attribute 'isnum'
