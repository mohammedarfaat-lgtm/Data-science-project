# %%
converted_integer = int(456.789)
print(converted_integer)
# Out:
# 456

# %%
converted_float = float("123.456")
print(converted_float)
# Out:
# 123.456

# %%
converted_integer = int(True)
print(converted_integer)
# Out:
# 1

# %%
converted_float = float(False)
print(converted_float)
# Out:
# 0.0

# %%
converted_boolean = bool(0)
print(converted_boolean)
# Out:
# False

# %%
converted_boolean = bool("0")
print(converted_boolean)
# Out:
# True

# %%
converted_boolean = bool("False")
print(converted_boolean)
# Out:
# True
