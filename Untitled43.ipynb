# %%
import pandas as pd

# %%
data={
    "Name":["Alice","Bob","Charlie","David"],
    "age":[25,30,35,40]
}

display(data)
# Out:
# {'Name': ['Alice', 'Bob', 'Charlie', 'David'], 'age': [25, 30, 35, 40]}

# %%
data={
    "Name":["Alice","Bob","Charlie","David"],
    "Age":[25,30,35,40]
}
df=pd.DataFrame(data)
display(df)
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35
# 3    David   40

# %%
#two label data structure

# %%
df.head()
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35
# 3    David   40

# %%
df.head(3)
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35

# %%
df.tail(2)
# Out:
#       Name  Age
# 2  Charlie   35
# 3    David   40

# %%
df["Name"]
# Out:
# 0      Alice
# 1        Bob
# 2    Charlie
# 3      David
# Name: Name, dtype: object

# %%
df["Age"]
# Out:
# 0    25
# 1    30
# 2    35
# 3    40
# Name: Age, dtype: int64

# %%
df[["Name","Age"]]
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35
# 3    David   40

# %%
df[df["Age"]>=30]
# Out:
#       Name  Age
# 1      Bob   30
# 2  Charlie   35
# 3    David   40

# %%
df["Grade"]=["A","B","C","D"]
display(df)
# Out:
#       Name  Age Grade
# 0    Alice   25     A
# 1      Bob   30     B
# 2  Charlie   35     C
# 3    David   40     D

# %%
df.drop("Grade",axis=1,inplace=True)
display(df)
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35
# 3    David   40

# %%
data = {'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve', 'Frank', 'Grace', 'Hannah', 'Isaac', 'Jack'],
        'Age': [25, 30, 35, 40, 45, 50, 55, 60, 65, 70],
        'Gender': ['F', 'M', 'M', 'M', 'F', 'M', 'F', 'F', 'M', 'M'],
        'Salary': [50000, 60000, 70000, 80000, 90000, 100000, 110000, 120000, 130000, 140000],
        'Department': ['HR', 'Finance', 'IT', 'Finance', 'HR', 'IT', 'HR', 'IT', 'Finance', 'HR']}

df = pd.DataFrame(data)
display(df)
# Out:
#       Name  Age Gender  Salary Department
# 0    Alice   25      F   50000         HR
# 1      Bob   30      M   60000    Finance
# 2  Charlie   35      M   70000         IT
# 3    David   40      M   80000    Finance
# 4      Eve   45      F   90000         HR
# 5    Frank   50      M  100000         IT
# 6    Grace   55      F  110000         HR
# 7   Hannah   60      F  120000         IT
# 8    Isaac   65      M  130000    Finance
# 9     Jack   70      M  140000         HR

# %%
filterdage=df[df["Age"]>40]
display(filterdage)
# Out:
#      Name  Age Gender  Salary Department
# 4     Eve   45      F   90000         HR
# 5   Frank   50      M  100000         IT
# 6   Grace   55      F  110000         HR
# 7  Hannah   60      F  120000         IT
# 8   Isaac   65      M  130000    Finance
# 9    Jack   70      M  140000         HR

# %%
filter_df2=df[(df["Gender"]=="F") & (df["Department"]=="HR")]
display(filter_df2)
# Out:
#     Name  Age Gender  Salary Department
# 0  Alice   25      F   50000         HR
# 4    Eve   45      F   90000         HR
# 6  Grace   55      F  110000         HR

# %%
s=df[(df["Gender"]=="M") & (df["Department"]=="HR")]
display(s)
# Out:
#    Name  Age Gender  Salary Department
# 9  Jack   70      M  140000         HR

# %%
df["Age"]>40
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# Name: Age, dtype: bool

# %%
s=df[df["Salary"].between(60000,110000)]
display(s)
# Out:
#       Name  Age Gender  Salary Department
# 1      Bob   30      M   60000    Finance
# 2  Charlie   35      M   70000         IT
# 3    David   40      M   80000    Finance
# 4      Eve   45      F   90000         HR
# 5    Frank   50      M  100000         IT
# 6    Grace   55      F  110000         HR

# %%
s=df[df["Name"].str.startswith("A") | df["Name"].str.endswith("e")]
display(s)
# Out:
#       Name  Age Gender  Salary Department
# 0    Alice   25      F   50000         HR
# 2  Charlie   35      M   70000         IT
# 4      Eve   45      F   90000         HR
# 6    Grace   55      F  110000         HR

# %%
data = {'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve', 'Frank', 'Grace', 'Hannah', 'Isaac', 'Jack'],
        'Age': [25, 30, 35, 40, 45, 50, 55, 60, 65, 70],
        'Gender': ['F', 'M', 'M', 'M', 'F', 'M', 'F', 'F', 'M', 'M'],
        'Salary': [50000, 60000, 70000, 80000, 90000, 100000, 110000, 120000, 130000, 140000],
        'Department': ['HR', 'Finance', 'IT', 'Finance', 'HR', 'IT', 'HR', 'IT', 'Finance', 'HR']}

df = pd.DataFrame(data)
display(df)
# Out:
#       Name  Age Gender  Salary Department
# 0    Alice   25      F   50000         HR
# 1      Bob   30      M   60000    Finance
# 2  Charlie   35      M   70000         IT
# 3    David   40      M   80000    Finance
# 4      Eve   45      F   90000         HR
# 5    Frank   50      M  100000         IT
# 6    Grace   55      F  110000         HR
# 7   Hannah   60      F  120000         IT
# 8    Isaac   65      M  130000    Finance
# 9     Jack   70      M  140000         HR

# %%
# task given by sir

# %%
avg_salary=df["Age"].mean()
avg_salary
# Out:
# np.float64(47.5)

# %%
no_of_employess=df["Name"].count()
no_of_employess
# Out:
# np.int64(10)

# %%
highest_salary=df["Salary"].max()
highest_salary
# Out:
# 140000

# %%
highest_salary=df["Salary"].sum()
highest_salary
# Out:
# np.int64(950000)

# %%
male_in_it=df[(df["Gender"]=="M") & (df["Department"]=="IT")]
male_in_it
# Out:
#       Name  Age Gender  Salary Department
# 2  Charlie   35      M   70000         IT
# 5    Frank   50      M  100000         IT

# %%
longes_name_employes=df["Name"].str.len().idxmax()
longes_name_employes
# Out:
# 2

# %%
name2=df["Name"].str.len()
max_length=name2.max()
longest_name_employee=df[name2==max_length]
display(longest_name_employee)
# Out:
#       Name  Age Gender  Salary Department
# 2  Charlie   35      M   70000         IT

# %%
highest_avg_salary=df.groupby("Department")["Salary"].mean()
highest_avg_salary
# Out:
# Department
# Finance    90000.000000
# HR         97500.000000
# IT         96666.666667
# Name: Salary, dtype: float64

# %%
highest_avg_salary=df.groupby("Department")["Salary"].mean().max()
highest_avg_salary
# Out:
# 97500.0

# %%
highest_avg_salary=df.groupby("Department")["Age"].mean().max()
highest_avg_salary
# Out:
# 48.75

# %%
#Which department has the highest average salary?**

# %%
has=df.groupby("Department")["Salary"].mean().idxmax()

has
# Out:
# 'HR'

# %%
#which employee has longest name

# %%
df["Name"]
# Out:
# 0      Alice
# 1        Bob
# 2    Charlie
# 3      David
# 4        Eve
# 5      Frank
# 6      Grace
# 7     Hannah
# 8      Isaac
# 9       Jack
# Name: Name, dtype: object

# %%
df["Name"].apply(len)
# Out:
# 0    5
# 1    3
# 2    7
# 3    5
# 4    3
# 5    5
# 6    5
# 7    6
# 8    5
# 9    4
# Name: Name, dtype: int64

# %%
df["Name"].apply(len).idxmax()
# Out:
# 2

# %%
df["Name"].apply(len).idxmax(),"Name"
# Out:
# (2, 'Name')

# %%
longest_name=df.loc[df["Name"].apply(len).idxmax(),"Name"]
longest_name
# Out:
# 'Charlie'

# %%
data = {'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve', 'Frank', 'Grace', 'Hannah', 'Isaac', 'Jack'],
        'Age': [25, 30, 35, 40, 45, 50, 55, 60, 65, 70],
        'Gender': ['F', 'M', 'M', 'M', 'F', 'M', 'F', 'F', 'M', 'M'],
        'Salary': [50000, 60000, 70000, 80000, 90000, 100000, 110000, 120000, 130000, 140000],
        'Department': ['HR', 'Finance', 'IT', 'Finance', 'HR', 'IT', 'HR', 'IT', 'Finance', 'HR']}

df = pd.DataFrame(data)
display(df)
# Out:
#       Name  Age Gender  Salary Department
# 0    Alice   25      F   50000         HR
# 1      Bob   30      M   60000    Finance
# 2  Charlie   35      M   70000         IT
# 3    David   40      M   80000    Finance
# 4      Eve   45      F   90000         HR
# 5    Frank   50      M  100000         IT
# 6    Grace   55      F  110000         HR
# 7   Hannah   60      F  120000         IT
# 8    Isaac   65      M  130000    Finance
# 9     Jack   70      M  140000         HR

# %%
display(df.head())
display(df.tail())
# Out:
#       Name  Age Gender  Salary Department
# 0    Alice   25      F   50000         HR
# 1      Bob   30      M   60000    Finance
# 2  Charlie   35      M   70000         IT
# 3    David   40      M   80000    Finance
# 4      Eve   45      F   90000         HR
#      Name  Age Gender  Salary Department
# 5   Frank   50      M  100000         IT
# 6   Grace   55      F  110000         HR
# 7  Hannah   60      F  120000         IT
# 8   Isaac   65      M  130000    Finance
# 9    Jack   70      M  140000         HR

# %%
display(df.shape)
# Out:
# (10, 5)

# %%
display(df.columns)
# Out:
# Index(['Name', 'Age', 'Gender', 'Salary', 'Department'], dtype='object')

# %%
df["Name"]
# Out:
# 0      Alice
# 1        Bob
# 2    Charlie
# 3      David
# 4        Eve
# 5      Frank
# 6      Grace
# 7     Hannah
# 8      Isaac
# 9       Jack
# Name: Name, dtype: object

# %%
df[["Name","Age","Salary"]]
# Out:
#       Name  Age  Salary
# 0    Alice   25   50000
# 1      Bob   30   60000
# 2  Charlie   35   70000
# 3    David   40   80000
# 4      Eve   45   90000
# 5    Frank   50  100000
# 6    Grace   55  110000
# 7   Hannah   60  120000
# 8    Isaac   65  130000
# 9     Jack   70  140000

# %%
(df.loc[4])
# Out:
# Name            Eve
# Age              45
# Gender            F
# Salary        90000
# Department       HR
# Name: 4, dtype: object

# %%
df[df["Age"]>50]
# Out:
#      Name  Age Gender  Salary Department
# 6   Grace   55      F  110000         HR
# 7  Hannah   60      F  120000         IT
# 8   Isaac   65      M  130000    Finance
# 9    Jack   70      M  140000         HR

# %%
df.isnull()
# Out:
#     Name    Age  Gender  Salary  Department
# 0  False  False   False   False       False
# 1  False  False   False   False       False
# 2  False  False   False   False       False
# 3  False  False   False   False       False
# 4  False  False   False   False       False
# 5  False  False   False   False       False
# 6  False  False   False   False       False
# 7  False  False   False   False       False
# 8  False  False   False   False       False
# 9  False  False   False   False       False

# %%
df.dropna()
# Out:
#       Name  Age Gender  Salary Department
# 0    Alice   25      F   50000         HR
# 1      Bob   30      M   60000    Finance
# 2  Charlie   35      M   70000         IT
# 3    David   40      M   80000    Finance
# 4      Eve   45      F   90000         HR
# 5    Frank   50      M  100000         IT
# 6    Grace   55      F  110000         HR
# 7   Hannah   60      F  120000         IT
# 8    Isaac   65      M  130000    Finance
# 9     Jack   70      M  140000         HR

# %%
df.fillna(0)
# Out:
#       Name  Age Gender  Salary Department
# 0    Alice   25      F   50000         HR
# 1      Bob   30      M   60000    Finance
# 2  Charlie   35      M   70000         IT
# 3    David   40      M   80000    Finance
# 4      Eve   45      F   90000         HR
# 5    Frank   50      M  100000         IT
# 6    Grace   55      F  110000         HR
# 7   Hannah   60      F  120000         IT
# 8    Isaac   65      M  130000    Finance
# 9     Jack   70      M  140000         HR

# %%
df.describe()
# Out:
#              Age         Salary
# count  10.000000      10.000000
# mean   47.500000   95000.000000
# std    15.138252   30276.503541
# min    25.000000   50000.000000
# 25%    36.250000   72500.000000
# 50%    47.500000   95000.000000
# 75%    58.750000  117500.000000
# max    70.000000  140000.000000

# %%
df["Salary"].mean()
# Out:
# np.float64(95000.0)

# %%
display(df["Age"].value_counts())
# Out:
# Age
# 25    1
# 30    1
# 35    1
# 40    1
# 45    1
# 50    1
# 55    1
# 60    1
# 65    1
# 70    1
# Name: count, dtype: int64

# %%
df.groupby("Department")["Salary"].mean()
# Out:
# Department
# Finance    90000.000000
# HR         97500.000000
# IT         96666.666667
# Name: Salary, dtype: float64

# %%
(df.sort_values(by="Age",ascending=True))
# Out:
#       Name  Age Gender  Salary Department
# 0    Alice   25      F   50000         HR
# 1      Bob   30      M   60000    Finance
# 2  Charlie   35      M   70000         IT
# 3    David   40      M   80000    Finance
# 4      Eve   45      F   90000         HR
# 5    Frank   50      M  100000         IT
# 6    Grace   55      F  110000         HR
# 7   Hannah   60      F  120000         IT
# 8    Isaac   65      M  130000    Finance
# 9     Jack   70      M  140000         HR

# %%
(df.sort_values(by="Age",ascending=False))
# Out:
#       Name  Age Gender  Salary Department
# 9     Jack   70      M  140000         HR
# 8    Isaac   65      M  130000    Finance
# 7   Hannah   60      F  120000         IT
# 6    Grace   55      F  110000         HR
# 5    Frank   50      M  100000         IT
# 4      Eve   45      F   90000         HR
# 3    David   40      M   80000    Finance
# 2  Charlie   35      M   70000         IT
# 1      Bob   30      M   60000    Finance
# 0    Alice   25      F   50000         HR

# %%
def double_age(x):
    return x*2

print(df["Age"].apply(double_age))
# Out:
# 0     50
# 1     60
# 2     70
# 3     80
# 4     90
# 5    100
# 6    110
# 7    120
# 8    130
# 9    140
# Name: Age, dtype: int64

# %%
def salary_increment(x):
     return x*0.05

print(df["Salary"].apply(salary_increment))
# Out:
# 0    2500.0
# 1    3000.0
# 2    3500.0
# 3    4000.0
# 4    4500.0
# 5    5000.0
# 6    5500.0
# 7    6000.0
# 8    6500.0
# 9    7000.0
# Name: Salary, dtype: float64
