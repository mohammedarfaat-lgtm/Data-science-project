# %%
from datetime import datetime

# %%
now = datetime.now()
print("current date and time:",now)
# Out:
# current date and time: 2025-12-09 17:19:50.543426

# %%
now = datetime.datetime.now()
print("current date and time:",now)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1902113792.py in <cell line: 0>()
# ----> 1 now = datetime.datetime.now()
#       2 print("current date and time:",now)
#
# AttributeError: type object 'datetime.datetime' has no attribute 'datetime'

# %%
date=datetime.date(2024, 9, 21)
print("specific date:",date)

# %%
year = date.year
month = date.month
day = date.day
print("year:",year,"month:",month,"day:",day)
# Out:
# year: <attribute 'year' of 'datetime.date' objects> month: <attribute 'month' of 'datetime.date' objects> day: <attribute 'day' of 'datetime.date' objects>

# %%
formatted_date=date.strftime("%y-%m-%d")
print("formatted date:",formatted_date)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3224693985.py in <cell line: 0>()
# ----> 1 formatted_date=date.strftime("%y-%m-%d")
#       2 print("formatted date:",formatted_date)
#
# TypeError: descriptor 'strftime' for 'datetime.date' objects doesn't apply to a 'str' object

# %%
now = datetime.datetime.now()
print("Current date and time:", now)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-2176495896.py in <cell line: 0>()
# ----> 1 now = datetime.datetime.now()
#       2 print("Current date and time:", now)
#
# AttributeError: type object 'datetime.datetime' has no attribute 'datetime'

# %%
now = datetime.datetime.now()
print("current date and time:",now)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-3717123384.py in <cell line: 0>()
# ----> 1 now = datetime.datetime.now()
#       2 print("current date and time:",now)
#
# AttributeError: type object 'datetime.datetime' has no attribute 'datetime'

# %%
date_str = "2024-02-28"
parsed_date = datetime.datetime.strptime(date_str, "%Y-%m-%d").date()
print("Parsed date:", parsed_date)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-3141799111.py in <cell line: 0>()
#       1 date_str = "2024-02-28"
# ----> 2 parsed_date = datetime.datetime.strptime(date_str, "%Y-%m-%d").date()
#       3 print("Parsed date:", parsed_date)
#
# AttributeError: type object 'datetime.datetime' has no attribute 'datetime'
