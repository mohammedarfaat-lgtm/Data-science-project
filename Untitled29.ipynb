# %%
import datetime

# %%
now= datetime.datetime.now()
print("current date and time:",now)
# Out:
# current date and time: 2024-10-02 09:38:09.438634

# %%
date=datetime.date(2024,2,28)
print("specific date:",date)
# Out:
# specific date: 2024-02-28

# %%
year=date.year
month=date.month
day=date.day
print("year:",year, "month:",month, "day:",day)
# Out:
# year: 2024 month: 2 day: 28

# %%
## formatiing date

# %%
formatted_date=date.strftime("%Y-%m-%d")
print("formatted_date:",formatted_date)
# Out:
# formatted_date: 2024-02-28

# %%
date_str="2024-02-28"
parsed_date=datetime.datetime.strptime(date_str , "%Y-%m-%d").date()
print("parsed date:",parsed_date)
# Out:
# parsed date: 2024-02-28

# %%
tomorrow=date+datetime.timedelta(days=1)
print("tomorrow:",tomorrow)
# Out:
# tomorrow: 2024-02-29

# %%
yesterday=date-datetime.timedelta(days=1)
print("yesterday:",yesterday)
# Out:
# yesterday: 2024-02-27

# %%
if date > yesterday:
  print("the date is after yesterday")
# Out:
# the date is after yesterday

# %%
day_of_week=date.weekday()
print("day of the week:", day_of_week)
# Out:
# day of the week: 2

# %%
time=datetime.time(14,30)
print("time:",time)
# Out:
# time: 14:30:00

# %%
hour=time.hour
minute=time.minute
print("hour:",hour,"minute:",minute)
# Out:
# hour: 14 minute: 30

# %%
date_time=datetime.datetime.combine(date,time)
print("date_time:",date_time)
# Out:
# date_time: 2024-02-28 14:30:00

# %%
current_time=datetime.datetime.now().time()
print("current_time:",current_time)
# Out:
# current_time: 09:38:45.049867

# %%
formatted_time=time.strftime("%H:%M:%S")
print("formatted_time:",formatted_time)
# Out:
# formatted_time: 14:30:00

# %%
later_time=(datetime.datetime.combine(datetime.date.today(),time)+datetime.timedelta(hours=2)).time()
print("Two hours later:",later_time)
# Out:
# Two hours later: 16:30:00

# %%
earlier_time = (datetime.datetime.combine(datetime.date.today(), time) - datetime.timedelta(minutes=30)).time()
print("Thirty minutes earlier:", earlier_time)
# Out:
# Thirty minutes earlier: 14:00:00

# %%
if time > earlier_time:
    print("The time is later than thirty minutes earlier.")
# Out:
# The time is later than thirty minutes earlier.

# %%
time_difference = datetime.datetime.combine(datetime.date.today(), time)- datetime.datetime.combine(datetime.date.today(), earlier_time)
print("Time difference:", time_difference)
# Out:
# Time difference: 0:30:00

# %%
seconds = time_difference.total_seconds()
print("Seconds:", seconds)
# Out:
# Seconds: 1800.0

# %%
from datetime import date

# %%
start_date = date(2024, 1, 1)
end_date = date(2024, 2, 28)
delta = end_date - start_date
print("Number of days:", delta.days)
# Out:
# Number of days: 58

# %%
# condition for leap year is
*( 1)divisible by 4, but not divisible by 100,)
*(2) eithe divisible by 4, divisible by 100, divisible by 400
# Out:
#   File "<ipython-input-7-d11deb1e927b>", line 2
#     *( 1)divisible by 4, but not divisible by 100,)
#                                                   ^
# SyntaxError: unmatched ')'

# %%
year=2024
is_leap=year%4==0 and (year%100!=0 or year%400==0)
print(f"{year} is leap year:" if is_leap else f"{year} is not a leap year." )
# Out:
# 2024 is leap year:

# %%
from datetime import date

# %%
date=date(2024,10,9)
week_number=date.isocalendar()[1]
print("week number:", week_number)
# Out:
# week number: 41

# %%
from datetime import date

# %%
import calendar
year = 2024
month = 2
first_day = date(year, month, 1)
last_day = date(year, month, calendar.monthrange(year, month)[1])
print("First day:", first_day, "Last day:", last_day)
# Out:
# First day: 2024-02-01 Last day: 2024-02-29

# %%
from datetime import datetime, timezone, timedelta

utc_time = datetime.now(timezone.utc)
local_time = utc_time.astimezone()
print("UTC time:", utc_time, "Local time:", local_time)
# Out:
# UTC time: 2024-10-16 07:54:26.276976+00:00 Local time: 2024-10-16 07:54:26.276976+00:00

# %%
from datetime import date
def calculate_age(birthdate):
    today = date.today()
    age = today.year - birthdate.year - ((today.month, today.day) < (birthdate.month, birthdate.day))
    return age

birthdate = date(2000, 8, 22)
age = calculate_age(birthdate)
print("Age:", age)
# Out:
# Age: 24

# %%
# only in a week it shows date not in a month ( monday=0, tuesday=1, wednesday=2, thursday=3, friday=4, saturday=5, sunday=6)

# %%
def next_weekday(d, weekday):
    days_ahead = weekday - d.weekday()
    if days_ahead <= 0:
        days_ahead += 7
    return d + timedelta(days_ahead)

next_tuesday = next_weekday(date.today(), 6)
print("Next tuesday :", next_tuesday)
# Out:
# Next tuesday : 2024-10-27

# %%
def next_weekday(d, weekday):
     days_ahead=weekday - d.weekday()
     if days_ahead<=0:
        days_ahead+=7
     return d + timedelta(days_ahead)

next_sunday= next_weekday(date.today(), 6)
print("next sunday:", next_sunday)
# Out:
# next sunday: 2024-10-27

# %%
def next_weekday(d, weekday):
  days_ahead=weekday-d.weekday()
  if days_ahead=weekday-d.weekday()
# Out:
# Next tuesday : 2024-10-25

# %%
# Out:
# Next Friday: 2024-10-25

# %%
# Out:
# Next thursday : 2024-10-18

# %%
# Out:
# Next Friday: 2024-10-18

# %%
# Out:
# Next thursday : 2024-10-18
