# %%
for i in range(10):
  print(i)

# %%
for i in range (1,11):
  print(i,"hello world")

# %%
for i in range(1,11):
  print(i,"ram")

# %%
for i in range (10):
  print(i,"varun sir ")

# %%
for i in range (1,11):
  i=i+5
  print(i,"hello world")

# %%
for i in range(1,21):
  i=i+10
  print(i,"hello world")

# %%
fruits=["apple","banana","cherry","arfath"]
for i in fruits:
  print(fruits)

# %%
for i in range (10):
  print(i,"hello world")
# Out:
# 0 hello world
# 1 hello world
# 2 hello world
# 3 hello world
# 4 hello world
# 5 hello world
# 6 hello world
# 7 hello world
# 8 hello world
# 9 hello world

# %%
# prompt: 1 to hello vertically 10 times with numbers

for i in range(1, 11):
  print(i)
  print("hello world")

# %%
for i in range(1, 11):
  print(i,"hello world")
# Out:
# 1 hello world
# 2 hello world
# 3 hello world
# 4 hello world
# 5 hello world
# 6 hello world
# 7 hello world
# 8 hello world
# 9 hello world
# 10 hello world

# %%
fruits=["apple","banan","cherry"]
for i in fruits:
  print(fruits)
# Out:
# ['apple', 'banan', 'cherry']
# ['apple', 'banan', 'cherry']
# ['apple', 'banan', 'cherry']

# %%
for i in range(2,6):
  print(i)
# Out:
# 2
# 3
# 4
# 5

# %%
for letter in "hello":
  print(letter)
# Out:
# h
# e
# l
# l
# o

# %%
for i in range(5):
  if i==4:
    break
  print(i)
# Out:
# 0
# 1
# 2
# 3

# %%
for i in range(98,101):
  if i==101:
    break
  print(i)
# Out:
# 98
# 99
# 100

# %%
for i in range (50,101):
  print(i,"hello world")
# Out:
# 50 hello world
# 51 hello world
# 52 hello world
# 53 hello world
# 54 hello world
# 55 hello world
# 56 hello world
# 57 hello world
# 58 hello world
# 59 hello world
# 60 hello world
# 61 hello world
# 62 hello world
# 63 hello world
# 64 hello world
# 65 hello world
# 66 hello world
# 67 hello world
# 68 hello world
# 69 hello world
# 70 hello world
# 71 hello world
# 72 hello world
# 73 hello world
# 74 hello world
# 75 hello world
# 76 hello world
# 77 hello world
# 78 hello world
# 79 hello world
# 80 hello world
# 81 hello world
# 82 hello world
# 83 hello world
# 84 hello world
# 85 hello world
# 86 hello world
# 87 hello world
# 88 hello world
# 89 hello world
# 90 hello world
# 91 hello world
# 92 hello world
# 93 hello world
# 94 hello world
# 95 hello world
# 96 hello world
# 97 hello world
# 98 hello world
# 99 hello world
# 100 hello world

# %%
for i in range(2,11,2):
 print(i)
# Out:
# 2
# 4
# 6
# 8
# 10

# %%
for i in range(21,31,2):
  print(i)
# Out:
# 21
# 23
# 25
# 27
# 29

# %%
for i in range(9,91,9):
  print(i)
# Out:
# 9
# 18
# 27
# 36
# 45
# 54
# 63
# 72
# 81
# 90

# %%
for i in range(1,10):
  if i==5:
    continue
  print(i)
# Out:
# 1
# 2
# 3
# 4
# 6
# 7
# 8
# 9

# %%
for i in range(1,10):
  if i == 5:
      continue
  print(i)
# Out:
# 1
# 2
# 3
# 4
# 6
# 7
# 8
# 9

# %%
for letter in "hello":
  print(i)
# Out:
# 9
# 9
# 9
# 9
# 9

# %%
squares=[x**2 for x in range (5)]
print(squares)
# Out:
# [0, 1, 4, 9, 16]

# %%
squares=[x**2 for x in range(5)]
print(squares)
# Out:
# [0, 1, 4, 9, 16]

# %%
for fruit in reversed (["apple","banana","cherry"]):
     print(fruit)
# Out:
# cherry
# banana
# apple

# %%
for fruit in reversed(["apple","banana","cherry"]):
 print(fruit)
# Out:
# cherry
# banana
# apple

# %%
for fruit in reversed (range(1, 5)):
  print(fruit)
# Out:
# 4
# 3
# 2
# 1

# %%
for i in range(5,0,-1):
  print(i)
# Out:
# 5
# 4
# 3
# 2
# 1

# %%
for i in range(-1,-10,-2):
  print(i)
# Out:
# -1
# -3
# -5
# -7
# -9

# %%
for i in range (-1,-10, -2):
  print(i)
# Out:
# -1
# -3
# -5
# -7
# -9

# %%
for i in range (-1,-10, -2):
  print()
# Out:
# -1
# -3
# -5
# -7
# -9

# %%
numbers=range(50)
print(numbers)
# Out:
# range(0, 50)

# %%
for i in range(5,7):
   print(i)
# Out:
# 5
# 6

# %%
for i in range(0,10,2):
  print(i)
# Out:
# 0
# 2
# 4
# 6
# 8

# %%
for char in "python":
  print(char)
# Out:
# p
# y
# t
# h
# o
# n

# %%
first_char = my_string[0]
print(first_char)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b2c8bdad6cb8> in <cell line: 1>()
# ----> 1 first_char = my_string[0]
#       2 print(first_char)
#
# NameError: name 'my_string' is not defined
