# %%
my_string="my name is arfath"
first_char=my_string[-8]
print(first_char)
# Out:
# s

# %%
sentence="my name is arfath"
first_char=sentence[0]
last_char=sentence[-2]
print(last_char)
# Out:
# t

# %%
book = "sindu mam is very good girl"
substring=book[2:]
print(substring)
# Out:
# ndu m
