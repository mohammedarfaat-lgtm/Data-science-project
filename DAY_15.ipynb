# %%
import pandas as pd

# %%
df=pd.read_csv("emp Data.csv")

# %%
df
# Out:
#       Sn Emp First Name Employee last name Unnamed: 3                   City  \
# 0    1.0            Ram                  A      20000              Bangalore
# 1    2.0           Alex                  F      45000                  Delhi
# 2    3.0       Salamaan               Khan      50000                  Patna
# 3    4.0         Yograj              Gupla      15000                 Punjab
# 4    5.0          Krish             Sharma      10000                  Delhi
# 5    6.0         Salika                  O      45000                 Mumbai
# 6    7.0          Pooja             Kumari      20000                Chennai
# 7    8.0      Pratiksha               Sing      50000                   Pune
# 8    9.0          Komal               Khan      80000                Madurai
# 9   10.0        ganeesh             Sharma      66000                Ayodhya
# 10   NaN            NaN                NaN        NaN                    NaN
# ...

# %%
df.to_csv("titanic.csv, index=false")
df
# Out:
#       Sn Emp First Name Employee last name Unnamed: 3                   City  \
# 0    1.0            Ram                  A      20000              Bangalore
# 1    2.0           Alex                  F      45000                  Delhi
# 2    3.0       Salamaan               Khan      50000                  Patna
# 3    4.0         Yograj              Gupla      15000                 Punjab
# 4    5.0          Krish             Sharma      10000                  Delhi
# 5    6.0         Salika                  O      45000                 Mumbai
# 6    7.0          Pooja             Kumari      20000                Chennai
# 7    8.0      Pratiksha               Sing      50000                   Pune
# 8    9.0          Komal               Khan      80000                Madurai
# 9   10.0        ganeesh             Sharma      66000                Ayodhya
# 10   NaN            NaN                NaN        NaN                    NaN
# ...
